# %%
import pandas as pd

# %%
import requests

# %%
res=requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
js=res.json()

# %%
js[0]['title']
# Out:
# 'Fix pylint use-a-generator warning'

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49562',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49562/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49562/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49562/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49562',
#   'id': 1437694784,
#   'node_id': 'PR_kwDOAA0YD85CSrp8',
#   'number': 49562,
#   'title': 'Fix pylint use-a-generator warning',
#   'user': {'login': 'Moisan',
#    'id': 31669,
#    'node_id': 'MDQ6VXNlcjMxNjY5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31669?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Moisan',
#    'html_url': 'https://github.com/Moisan',
#    'followers_url': 'https://api.github.com/users/Moisan/followers',
#    'following_url': 'https://api.github.com/users/Moisan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Moisan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Moisan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Moisan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Moisan/orgs',
#    'repos_url': 'https://api.github.com/users/Moisan/repos',
#    'events_url': 'https://api.github.com/users/Moisan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Moisan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-07T03:05:49Z',
#   'updated_at': '2022-11-07T03:05:49Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49562',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49562',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49562.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49562.patch',
#    'merged_at': None},
#   'body': 'Related to https://github.com/pandas-dev/pandas/issues/48855\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49562/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49562/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49561',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49561/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49561/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49561/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/49561',
#   'id': 1437669869,
#   'node_id': 'I_kwDOAA0YD85VsRnt',
#   'number': 49561,
#   'title': 'BUG: pd.read_sql with sql can failed when running query with % character',
#   'user': {'login': 'WindSoilder',
#    'id': 22256154,
#    'node_id': 'MDQ6VXNlcjIyMjU2MTU0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22256154?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WindSoilder',
#    'html_url': 'https://github.com/WindSoilder',
#    'followers_url': 'https://api.github.com/users/WindSoilder/followers',
#    'following_url': 'https://api.github.com/users/WindSoilder/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/WindSoilder/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/WindSoilder/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/WindSoilder/subscriptions',
#    'organizations_url': 'https://api.github.com/users/WindSoilder/orgs',
#    'repos_url': 'https://api.github.com/users/WindSoilder/repos',
#    'events_url': 'https://api.github.com/users/WindSoilder/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/WindSoilder/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-07T02:20:31Z',
#   'updated_at': '2022-11-07T02:24:22Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [x] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\nimport sqlalchemy\r\n# the database server need to be mysql, and we need to connect to server\r\nengine = sqlalchemy.create_engine("mysql://a:b@localhost")\r\npd.read_sql("select a from x WHERE b LIKE %2%", engine)\r\n```\r\n\r\n\r\n\r\n### Issue Description\r\n\r\n1. firstly we need to have a mysql server\r\n2. then execute the code in reproducible example\r\n3. an exception occured: `ValueError: unsupported format character \'%\' (0x25) at index 31`\r\n\r\n\r\n### Expected Behavior\r\n\r\npandas shouldn\'t raise ValueError.\r\n\r\nIn addition: I\'ve confimed it works fine on version 1.1.*(like 1.1.3), the issue is happend when `pandas >= 1.2`\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 91111fd99898d9dcaa6bf6bedb662db4108da6e6\r\npython           : 3.8.13.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 4.14.105-19-0016\r\nVersion          : #1 SMP Wed Sep 23 19:31:42 CST 2020\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : en_US.UTF-8\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.5.1\r\nnumpy            : 1.22.4\r\npytz             : 2022.6\r\ndateutil         : 2.8.2\r\nsetuptools       : 61.2.0\r\npip              : 21.2.4\r\nCython           : 0.29.28\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : 1.0.2\r\npsycopg2         : None\r\njinja2           : 2.11.2\r\nIPython          : 8.6.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           :\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.7.3\r\nsnappy           : None\r\nsqlalchemy       : 1.4.42\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49561/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49561/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49560',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49560/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49560/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49560/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49560',
#   'id': 1437564458,
#   'node_id': 'PR_kwDOAA0YD85CSQ0n',
#   'number': 49560,
#   'title': 'DEPR: Remove int64 uint64 float64 index part 1',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-06T22:32:20Z',
#   'updated_at': '2022-11-07T03:48:25Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49560',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49560',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49560.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49560.patch',
#    'merged_at': None},
#   'body': "*Not ready for review, I still need to see if the errors in the CI are different than locally*\r\n\r\nI had some problems with #49494, so I'm closing that and trying again with a more focused PR.\r\n\r\nThis PR makes progress towards removing Int64Index, UInt64Index & FloatIndex from the code base, see #42717.\r\n\r\nIn this PR I make instantiation of `Index` with numpy numeric dtypes return a `NumericIndex` with the given dtype rather than converting to the old 64 bit only numeric index types, making all numeric dtypes available for indexes.\r\n\r\nThis is just the first part of the changes planned. In follow-ups PRs I will:\r\n* remove Int64Index, Uint64Index & Float64Index from the top namespace\r\n* remove Int64Index, Uint64Index & Float64Index from the code base entirely (also internally)\r\n* Move the functionality of `NumericIndex`into the base `Index` and remove `NumericIndex`\r\n* Update docs to reflect the above changes\r\n\r\n## related PRs\r\nA part of the problems I had in #49494 was a few corner case bugs. They're pulled out into seperate PRs (#49536 & #49540). They're present in this PR at present, but will be removed after those seperate PRs have been merged.\r\n\r\n## Notable changes from this PR:\r\nAs mentioned in #49494, one notable change from the PR is that because we now have all the numeric dtypes available for indexes, indexes created from DateTimeIndex (day, year etc.) will now be in int32, where previously they were forced to int64 (because that was the only index integer dtype available).\r\n\r\nUsing int32 is the more correct way, because the underlying `DateTimeArray` returns 32bit arrays. An example of this:\r\n\r\n```ipython\r\n>>> import pandas as pd\r\n>>> \r\n>>> x = pd.date_range(start='1/1/2018', end='1/08/2018')\r\n>>> x.array.day\r\narray([1, 2, 3, 4, 5, 6, 7, 8], dtype=int32)  # 32bit, current and will not be changed in this series of PRs\r\n>>> x.day\r\nInt64Index([1, 2, 3, 4, 5, 6, 7, 8], dtype='int64')  # before this PR\r\nNumericIndex([1, 2, 3, 4, 5, 6, 7, 8], dtype='int32')  # after this PR\r\nIndex([1, 2, 3, 4, 5, 6, 7, 8], dtype='int32')  # after follow-up PRs\r\n```\r\n\r\nThe above will be included in the doc changes, when I do the docs\r\n\r\nProgress towards #42717. See also #41272",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49560/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49560/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49558',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49558/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49558/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49558/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49558',
#   'id': 1437421997,
#   'node_id': 'PR_kwDOAA0YD85CR1aO',
#   'number': 49558,
#   'title': 'BUG/PERF: MultiIndex.value_counts returning flat index',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 71268330,
#     'node_id': 'MDU6TGFiZWw3MTI2ODMzMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/MultiIndex',
#     'name': 'MultiIndex',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-11-06T14:22:30Z',
#   'updated_at': '2022-11-06T23:14:35Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49558',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49558',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49558.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49558.patch',
#    'merged_at': None},
#   'body': '- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.0.0.rst` file if fixing a bug or adding a new feature.\r\n\r\n\r\nI believe it is a bug that `MultiIndex.value_counts` returns a `Series` indexed by a flat index of tuples rather than a `MultiIndex`. By returning a flat index, we lose nullable dtypes, index names, etc.\r\n\r\nThis PR changes `MultiIndex.value_counts` to return a `Series` indexed by a `MultiIndex`. \r\n\r\nThis also has some perf improvements:\r\n\r\n```\r\nimport pandas as pd\r\nimport numpy as np\r\n\r\nmi = pd.MultiIndex.from_product([np.arange(1000), np.arange(1000)])\r\n\r\n%timeit mi.value_counts()\r\n\r\n974 ms ± 28.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)  <- main\r\n182 ms ± 10.2 ms per loop (mean ± std. dev. of 7 runs, 10 loops each) <- PR\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49558/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49558/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49557',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49557/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49557/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49557/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49557',
#   'id': 1437413301,
#   'node_id': 'PR_kwDOAA0YD85CRztm',
#   'number': 49557,
#   'title': 'ENH/CoW: use lazy copy in set_index method',
#   'user': {'login': 'Th3nn3ss',
#    'id': 25160953,
#    'node_id': 'MDQ6VXNlcjI1MTYwOTUz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25160953?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Th3nn3ss',
#    'html_url': 'https://github.com/Th3nn3ss',
#    'followers_url': 'https://api.github.com/users/Th3nn3ss/followers',
#    'following_url': 'https://api.github.com/users/Th3nn3ss/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Th3nn3ss/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Th3nn3ss/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Th3nn3ss/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Th3nn3ss/orgs',
#    'repos_url': 'https://api.github.com/users/Th3nn3ss/repos',
#    'events_url': 'https://api.github.com/users/Th3nn3ss/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Th3nn3ss/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-06T13:55:37Z',
#   'updated_at': '2022-11-06T13:55:37Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49557',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49557',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49557.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49557.patch',
#    'merged_at': None},
#   'body': 'Copy-on-Write in `set_index`\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\nThis PR is part of an effort to implement the Copy-on-Write implementation mentioned in #49473. More detail in this proposal https://docs.google.com/document/d/1ZCQ9mx3LBMy-nhwRl33_jgcvWo9IWdEfxDNQ2thyTb0/edit / with discussions in https://github.com/pandas-dev/pandas/issues/36195',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49557/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49557/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49556',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49556/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49556/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49556/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49556',
#   'id': 1437344089,
#   'node_id': 'PR_kwDOAA0YD85CRmaa',
#   'number': 49556,
#   'title': 'for gh-49508 changing Doc for DataFrame.astype',
#   'user': {'login': 'ramvikrams',
#    'id': 106332857,
#    'node_id': 'U_kgDOBlaCuQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/106332857?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ramvikrams',
#    'html_url': 'https://github.com/ramvikrams',
#    'followers_url': 'https://api.github.com/users/ramvikrams/followers',
#    'following_url': 'https://api.github.com/users/ramvikrams/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ramvikrams/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ramvikrams/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ramvikrams/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ramvikrams/orgs',
#    'repos_url': 'https://api.github.com/users/ramvikrams/repos',
#    'events_url': 'https://api.github.com/users/ramvikrams/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ramvikrams/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-06T09:35:49Z',
#   'updated_at': '2022-11-06T11:15:59Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49556',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49556',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49556.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49556.patch',
#    'merged_at': None},
#   'body': 'added the series in input in the doc of DataFrame.astype\r\n\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49556/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49556/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49555',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49555/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49555/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49555/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49555',
#   'id': 1437318794,
#   'node_id': 'PR_kwDOAA0YD85CRhep',
#   'number': 49555,
#   'title': 'ENH/CoW: use lazy copy on replace method',
#   'user': {'login': 'Th3nn3ss',
#    'id': 25160953,
#    'node_id': 'MDQ6VXNlcjI1MTYwOTUz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25160953?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Th3nn3ss',
#    'html_url': 'https://github.com/Th3nn3ss',
#    'followers_url': 'https://api.github.com/users/Th3nn3ss/followers',
#    'following_url': 'https://api.github.com/users/Th3nn3ss/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Th3nn3ss/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Th3nn3ss/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Th3nn3ss/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Th3nn3ss/orgs',
#    'repos_url': 'https://api.github.com/users/Th3nn3ss/repos',
#    'events_url': 'https://api.github.com/users/Th3nn3ss/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Th3nn3ss/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-11-06T07:47:04Z',
#   'updated_at': '2022-11-06T14:06:51Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49555',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49555',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49555.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49555.patch',
#    'merged_at': None},
#   'body': '- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\nThis PR is part of an effort to implement the Copy-on-Write implementation mentioned in #49473. More detail in this proposal https://docs.google.com/document/d/1ZCQ9mx3LBMy-nhwRl33_jgcvWo9IWdEfxDNQ2thyTb0/edit / with discussions in https://github.com/pandas-dev/pandas/issues/36195',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49555/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49555/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49553',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49553/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49553/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49553/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/49553',
#   'id': 1437314863,
#   'node_id': 'I_kwDOAA0YD85Vq68v',
#   'number': 49553,
#   'title': 'ENH: Expose date parsing arguments in `read_html` function',
#   'user': {'login': 'csala',
#    'id': 6129283,
#    'node_id': 'MDQ6VXNlcjYxMjkyODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6129283?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/csala',
#    'html_url': 'https://github.com/csala',
#    'followers_url': 'https://api.github.com/users/csala/followers',
#    'following_url': 'https://api.github.com/users/csala/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/csala/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/csala/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/csala/subscriptions',
#    'organizations_url': 'https://api.github.com/users/csala/orgs',
#    'repos_url': 'https://api.github.com/users/csala/repos',
#    'events_url': 'https://api.github.com/users/csala/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/csala/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-11-06T07:28:13Z',
#   'updated_at': '2022-11-06T07:41:55Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Feature Type\n\n- [X] Adding new functionality to pandas\n\n- [ ] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\nThe current `read_html` function exposes the same `parse_dates` argument that `read_csv` has, but it does not expose the rest of arguments that let the user control how the dates are parsed (`infer_datetime_format`, `keep_date_col`, `date_parser`, `dayfirst`, `cache_dates`).\r\n\r\nOther arguments unrelated to date parsing may be in the same situation, so maybe this issue could be extended to cover them all.\n\n### Feature Description\n\nThese arguments, or at least some of them, could be easily exposed directly in the `read_html` without much hassle, which would be very convenient for the user.\n\n### Alternative Solutions\n\nRight now the only viable solution is to skip date parsing altogether during the data loading step and then manually implement the date parsing over the returned data frame.\r\n\r\nThe problem with this is that it breaks the API uniformity with `read_csv`, making the implementation of integrations with different input data sources different depending on the data format (function call with arguments vs function call with arguments + postprocessing), while also potentially skipping any optimizations implemented during the `read_csv` workflow.\n\n### Additional Context\n\nFrom what I could tell skimming over the code, the `read_html` function only adds a few layers of code on top of the underlying parser, which already supports all the mentioned arguments, and `parse_dates` is simply pushed down to it untouched letting the parser use the default values for all the others arguments in the list above.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49553/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49553/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49552',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49552/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49552/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49552/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49552',
#   'id': 1437267165,
#   'node_id': 'PR_kwDOAA0YD85CRX3M',
#   'number': 49552,
#   'title': 'DEPR: enforce a bunch',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2022-11-06T03:04:51Z',
#   'updated_at': '2022-11-07T04:08:42Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49552',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49552',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49552.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49552.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49552/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49552/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49551',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49551/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49551/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49551/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49551',
#   'id': 1437194901,
#   'node_id': 'PR_kwDOAA0YD85CRJjM',
#   'number': 49551,
#   'title': 'DEPR: Enforce deprecation of numeric_only=None in DataFrame aggregations',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'},
#    {'id': 1049312478,
#     'node_id': 'MDU6TGFiZWwxMDQ5MzEyNDc4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/DataFrame',
#     'name': 'DataFrame',
#     'color': '370f77',
#     'default': False,
#     'description': 'DataFrame data structure'},
#    {'id': 2365504383,
#     'node_id': 'MDU6TGFiZWwyMzY1NTA0Mzgz',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reduction%20Operations',
#     'name': 'Reduction Operations',
#     'color': '547c03',
#     'default': False,
#     'description': 'sum, mean, min, max, etc.'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/42',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42/labels',
#    'id': 1945020,
#    'node_id': 'MDk6TWlsZXN0b25lMTk0NTAyMA==',
#    'number': 42,
#    'title': '2.0',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 39,
#    'closed_issues': 485,
#    'state': 'open',
#    'created_at': '2016-08-16T13:21:24Z',
#    'updated_at': '2022-11-07T02:42:13Z',
#    'due_on': '2022-12-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2022-11-05T21:40:10Z',
#   'updated_at': '2022-11-06T16:24:35Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49551',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49551',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49551.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49551.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49551/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49551/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49550',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49550/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49550/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49550/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49550',
#   'id': 1437186312,
#   'node_id': 'PR_kwDOAA0YD85CRH26',
#   'number': 49550,
#   'title': 'CLN: Deduplicate code in duplicated',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-05T21:03:42Z',
#   'updated_at': '2022-11-05T21:23:39Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49550',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49550',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49550.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49550.patch',
#    'merged_at': None},
#   'body': 'cc @mroeschke \r\nI think you asked for this when implementing the mask support',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49550/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49550/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49549',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49549/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49549/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49549/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49549',
#   'id': 1437159263,
#   'node_id': 'PR_kwDOAA0YD85CRCn4',
#   'number': 49549,
#   'title': 'ENH: Support mask in Int64Factorizer',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack, Explode'},
#    {'id': 1817503692,
#     'node_id': 'MDU6TGFiZWwxODE3NTAzNjky',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/NA%20-%20MaskedArrays',
#     'name': 'NA - MaskedArrays',
#     'color': '8cc645',
#     'default': False,
#     'description': 'Related to pd.NA and nullable extension arrays'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-05T19:23:28Z',
#   'updated_at': '2022-11-06T17:06:49Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49549',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49549',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49549.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49549.patch',
#    'merged_at': None},
#   'body': 'First step to support masks properly in merge. \r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49549/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49549/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49548',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49548/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49548/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49548/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49548',
#   'id': 1437158635,
#   'node_id': 'PR_kwDOAA0YD85CRCgJ',
#   'number': 49548,
#   'title': 'REF: remove unreachable maybe_cast_to_datetime cases',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
# ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49519/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49519/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49518',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49518/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49518/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49518/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49518',
#   'id': 1435779726,
#   'node_id': 'PR_kwDOAA0YD85CMe-j',
#   'number': 49518,
#   'title': 'STYLE/PERF: replace string concatenations with f-strings in core',
#   'user': {'login': 'akx',
#    'id': 58669,
#    'node_id': 'MDQ6VXNlcjU4NjY5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58669?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/akx',
#    'html_url': 'https://github.com/akx',
#    'followers_url': 'https://api.github.com/users/akx/followers',
#    'following_url': 'https://api.github.com/users/akx/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/akx/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/akx/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/akx/subscriptions',
#    'organizations_url': 'https://api.github.com/users/akx/orgs',
#    'repos_url': 'https://api.github.com/users/akx/repos',
#    'events_url': 'https://api.github.com/users/akx/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/akx/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 106935113,
#     'node_id': 'MDU6TGFiZWwxMDY5MzUxMTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Code%20Style',
#     'name': 'Code Style',
#     'color': 'eb6420',
#     'default': False,
#     'description': 'Code style, linting, code_checks'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-04T09:22:04Z',
#   'updated_at': '2022-11-05T07:02:30Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49518',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49518',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49518.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49518.patch',
#    'merged_at': None},
#   'body': 'Doing less concatenations and explicit cast calls in the core is likely to yield some performance improvements (see https://twitter.com/raymondh/status/1205969258800275456).\r\n\r\nSplit out of https://github.com/pandas-dev/pandas/pull/49229.\r\nRefs https://github.com/pandas-dev/pandas/issues/29547 (a 2019 issue tracking replacing formatting with better alternatives)\r\n\r\n- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49518/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49518/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49516',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49516/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49516/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49516/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/49516',
#   'id': 1435746616,
#   'node_id': 'I_kwDOAA0YD85Vk8E4',
#   'number': 49516,
#   'title': 'BUG: Full outer of single index dataframe on multi-index dataframe behavior not as expected',
#   'user': {'login': 'david6l34',
#    'id': 55838817,
#    'node_id': 'MDQ6VXNlcjU1ODM4ODE3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55838817?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/david6l34',
#    'html_url': 'https://github.com/david6l34',
#    'followers_url': 'https://api.github.com/users/david6l34/followers',
#    'following_url': 'https://api.github.com/users/david6l34/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/david6l34/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/david6l34/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/david6l34/subscriptions',
#    'organizations_url': 'https://api.github.com/users/david6l34/orgs',
#    'repos_url': 'https://api.github.com/users/david6l34/repos',
#    'events_url': 'https://api.github.com/users/david6l34/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/david6l34/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-04T08:51:16Z',
#   'updated_at': '2022-11-04T08:52:19Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd \r\nleft = pd.DataFrame(\r\n    {"A": ["A0", "A1", "A2"], "B": ["B0", "B1", "B2"]},\r\n    index=pd.Index(["K0", "K1", "K3"], name="key"),\r\n)\r\nindex = pd.MultiIndex.from_tuples(\r\n    [("K0", "Y0"), ("K1", "Y1"), ("K2", "Y2"), ("K2", "Y3")],\r\n    names=["key", "Y"],\r\n)\r\nright = pd.DataFrame(\r\n    {"C": ["C0", "C1", "C2", "C3"], "D": ["D0", "D1", "D2", "D3"]},\r\n    index=index,\r\n)\r\nresult = left.join(right, how="outer")\r\ndisplay(left, right, result)\r\n```\r\n![image](https://user-images.githubusercontent.com/55838817/199931749-9618e2cf-d0a9-41ff-9328-8c81e7f918b4.png)\r\n\r\n\r\n### Issue Description\r\n\r\nFull outer join of single index dataframe to multiindex dataframe does not work as expected.\r\n\r\n### Expected Behavior\r\n\r\nExpect there will be one extra record with key K3 like below\r\n\r\n\r\n\r\n![image](https://user-images.githubusercontent.com/55838817/199929548-bc280422-014b-4b65-9dcb-6ef028bb18c2.png)\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n### Installed Versions\r\n\r\n<details>\r\npython           : 3.10.6.final.0\r\npandas           : 1.5.0\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49516/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49516/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49510',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49510/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49510/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49510/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/49510',
#   'id': 1435271283,
#   'node_id': 'I_kwDOAA0YD85VjIBz',
#   'number': 49510,
#   'title': 'ENH: Parameter `keep_equal` in `.compare(...)` method should not rely on the `keep_shape` parameter',
#   'user': {'login': 'it176131',
#    'id': 13686957,
#    'node_id': 'MDQ6VXNlcjEzNjg2OTU3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13686957?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/it176131',
#    'html_url': 'https://github.com/it176131',
#    'followers_url': 'https://api.github.com/users/it176131/followers',
#    'following_url': 'https://api.github.com/users/it176131/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/it176131/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/it176131/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/it176131/subscriptions',
#    'organizations_url': 'https://api.github.com/users/it176131/orgs',
#    'repos_url': 'https://api.github.com/users/it176131/repos',
#    'events_url': 'https://api.github.com/users/it176131/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/it176131/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-03T21:20:30Z',
#   'updated_at': '2022-11-03T21:22:57Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Feature Type\n\n- [ ] Adding new functionality to pandas\n\n- [X] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\nThe [docs](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.compare.html) for the `keep_equal` parameter say:\r\n> **keep_equal**: **_bool, default False_**\r\nIf true, the result keeps values that are equal. Otherwise, equal values are shown as NaNs.\r\n\r\nI would expect the following code to return rows where the values in each `Series` are equal, but instead it is empty.\r\n\r\n```python\r\nimport numpy as np  # 1.23.3\r\nimport pandas as pd  # 1.5.1\r\n\r\nnp.random.seed(0)\r\n\r\ns0 = pd.Series(np.random.random(size=(5)))\r\ns1 = s0.copy()\r\n\r\nprint(s0.compare(s1, keep_equal=True))\r\n```\r\n```\r\nEmpty DataFrame\r\nColumns: [self, other]\r\nIndex: []\r\n```\r\n\r\nChanging the `keep_shape` parameter argument to `True` results in the expected results\r\n\r\n```python\r\nimport numpy as np  # 1.23.3\r\nimport pandas as pd  # 1.5.1\r\n\r\nnp.random.seed(0)\r\n\r\ns0 = pd.Series(np.random.random(size=(5)))\r\ns1 = s0.copy()\r\n\r\nprint(s0.compare(s1, keep_shape=True, keep_equal=True))\r\n```\r\n\r\n```\r\n       self     other\r\n0  0.548814  0.548814\r\n1  0.715189  0.715189\r\n2  0.602763  0.602763\r\n3  0.544883  0.544883\r\n4  0.423655  0.423655\r\n```\r\n\r\nI would like it if the latter output would be returned without having to change the `keep_shape` argument.\n\n### Feature Description\n\nAdd logic to [`.compare(...)`](https://github.com/pandas-dev/pandas/blob/91111fd99898d9dcaa6bf6bedb662db4108da6e6/pandas/core/generic.py#L9200) method so `keep_equal` can swap the underlying `mask`.\r\n\r\n# NOTE -- this has not been tested!\r\n```python\r\ndef compare(\r\n    self,\r\n    other,\r\n    align_axis: Axis = 1,\r\n    keep_shape: bool_t = False,\r\n    keep_equal: bool_t = False,\r\n    result_names: Suffixes = ("self", "other"),\r\n):\r\n    from pandas.core.reshape.concat import concat\r\n\r\n    if type(self) is not type(other):\r\n        cls_self, cls_other = type(self).__name__, type(other).__name__\r\n        raise TypeError(\r\n            f"can only compare \'{cls_self}\' (not \'{cls_other}\') with \'{cls_self}\'"\r\n        )\r\n\r\n    mask = ~((self == other) | (self.isna() & other.isna()))\r\n\r\n    if not keep_equal:\r\n        self = self.where(mask)\r\n        other = other.where(mask)\r\n    \r\n    # TODO -- negate the mask!\r\n    else:\r\n        self = self.mask(mask)\r\n        other = other.mask(mask)\r\n\r\n    ...\r\n```\n\n### Alternative Solutions\n\nUse the `.compare(...)` method as is, but remember to change the `keep_shape` argument from `False` to `True`.\r\n\r\n```python\r\nimport pandas as pd  # 1.5.1\r\n\r\nnp.random.seed(0)\r\n\r\ns0 = pd.Series(np.random.random(size=(5)))\r\ns1 = s0.copy()\r\n\r\nprint(s0.compare(s1, keep_shape=True, keep_equal=True))\r\n```\r\n\r\n```\r\n       self     other\r\n0  0.548814  0.548814\r\n1  0.715189  0.715189\r\n2  0.602763  0.602763\r\n3  0.544883  0.544883\r\n4  0.423655  0.423655\r\n```\n\n### Additional Context\n\nI could not find any existing issues related to the `keep_equal` parameter in `.compare`. However, I did find [this issue](https://github.com/pandas-dev/pandas/issues/48488) related to `tolerance` parameters.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49510/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49510/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
lis=[]

# %%
lis.append(js[0]['user'])

# %%
lis.append(js[1]['user'])

# %%
lis
# Out:
# [{'login': 'Moisan',
#   'id': 31669,
#   'node_id': 'MDQ6VXNlcjMxNjY5',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/31669?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Moisan',
#   'html_url': 'https://github.com/Moisan',
#   'followers_url': 'https://api.github.com/users/Moisan/followers',
#   'following_url': 'https://api.github.com/users/Moisan/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Moisan/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Moisan/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Moisan/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Moisan/orgs',
#   'repos_url': 'https://api.github.com/users/Moisan/repos',
#   'events_url': 'https://api.github.com/users/Moisan/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Moisan/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'WindSoilder',
#   'id': 22256154,
#   'node_id': 'MDQ6VXNlcjIyMjU2MTU0',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/22256154?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/WindSoilder',
#   'html_url': 'https://github.com/WindSoilder',
#   'followers_url': 'https://api.github.com/users/WindSoilder/followers',
#   'following_url': 'https://api.github.com/users/WindSoilder/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/WindSoilder/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/WindSoilder/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/WindSoilder/subscriptions',
#   'organizations_url': 'https://api.github.com/users/WindSoilder/orgs',
#   'repos_url': 'https://api.github.com/users/WindSoilder/repos',
#   'events_url': 'https://api.github.com/users/WindSoilder/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/WindSoilder/received_events',
#   'type': 'User',
#   'site_admin': False}]

# %%
for i in range(len(js)):
    lis.append(js[i]['user'])

# %%
pd.DataFrame(lis).to_csv("user.csv",index=False)

# %%
pd.read_csv('user.csv')
# Out:
#                  login         id               node_id  \
# 0               Moisan      31669      MDQ6VXNlcjMxNjY5
# 1          WindSoilder   22256154  MDQ6VXNlcjIyMjU2MTU0
# 2               Moisan      31669      MDQ6VXNlcjMxNjY5
# 3          WindSoilder   22256154  MDQ6VXNlcjIyMjU2MTU0
# 4           topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 5           lukemanley    8519523  MDQ6VXNlcjg1MTk1MjM=
# 6             Th3nn3ss   25160953  MDQ6VXNlcjI1MTYwOTUz
# 7           ramvikrams  106332857          U_kgDOBlaCuQ
# 8             Th3nn3ss   25160953  MDQ6VXNlcjI1MTYwOTUz
# 9                csala    6129283  MDQ6VXNlcjYxMjkyODM=
# 10        jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 11          rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 12               phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 13               phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 14        jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 15          rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 16        jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 17          topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 18          topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 19          topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 20   thlautenschlaeger   33692555  MDQ6VXNlcjMzNjkyNTU1
# 21            cdcadman   51368516  MDQ6VXNlcjUxMzY4NTE2
# 22        jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 23            noritada      20850      MDQ6VXNlcjIwODUw
# 24        arnaudlegout    7670869  MDQ6VXNlcjc2NzA4Njk=
# 25  jorisvandenbossche    1020496  MDQ6VXNlcjEwMjA0OTY=
# 26  jorisvandenbossche    1020496  MDQ6VXNlcjEwMjA0OTY=
# 27             anbjork   37732575  MDQ6VXNlcjM3NzMyNTc1
# 28  jorisvandenbossche    1020496  MDQ6VXNlcjEwMjA0OTY=
# 29                 akx      58669      MDQ6VXNlcjU4NjY5
# 30           david6l34   55838817  MDQ6VXNlcjU1ODM4ODE3
# 31            it176131   13686957  MDQ6VXNlcjEzNjg2OTU3
#
#                                            avatar_url  gravatar_id  \
# 0   https://avatars.githubusercontent.com/u/31669?v=4          NaN
# 1   https://avatars.githubusercontent.com/u/222561...          NaN
# 2   https://avatars.githubusercontent.com/u/31669?v=4          NaN
# 3   https://avatars.githubusercontent.com/u/222561...          NaN
# 4   https://avatars.githubusercontent.com/u/263644...          NaN
# 5   https://avatars.githubusercontent.com/u/851952...          NaN
# 6   https://avatars.githubusercontent.com/u/251609...          NaN
# 7   https://avatars.githubusercontent.com/u/106332...          NaN
# 8   https://avatars.githubusercontent.com/u/251609...          NaN
# 9   https://avatars.githubusercontent.com/u/612928...          NaN
# 10  https://avatars.githubusercontent.com/u/807896...          NaN
# 11  https://avatars.githubusercontent.com/u/455624...          NaN
# 12  https://avatars.githubusercontent.com/u/619347...          NaN
# 13  https://avatars.githubusercontent.com/u/619347...          NaN
# 14  https://avatars.githubusercontent.com/u/807896...          NaN
# 15  https://avatars.githubusercontent.com/u/455624...          NaN
# 16  https://avatars.githubusercontent.com/u/807896...          NaN
# 17  https://avatars.githubusercontent.com/u/263644...          NaN
# 18  https://avatars.githubusercontent.com/u/263644...          NaN
# 19  https://avatars.githubusercontent.com/u/263644...          NaN
# 20  https://avatars.githubusercontent.com/u/336925...          NaN
# 21  https://avatars.githubusercontent.com/u/513685...          NaN
# 22  https://avatars.githubusercontent.com/u/807896...          NaN
# 23  https://avatars.githubusercontent.com/u/20850?v=4          NaN
# 24  https://avatars.githubusercontent.com/u/767086...          NaN
# 25  https://avatars.githubusercontent.com/u/102049...          NaN
# 26  https://avatars.githubusercontent.com/u/102049...          NaN
# 27  https://avatars.githubusercontent.com/u/377325...          NaN
# 28  https://avatars.githubusercontent.com/u/102049...          NaN
# 29  https://avatars.githubusercontent.com/u/58669?v=4          NaN
# 30  https://avatars.githubusercontent.com/u/558388...          NaN
# 31  https://avatars.githubusercontent.com/u/136869...          NaN
#
#                                                 url  \
# 0               https://api.github.com/users/Moisan
# 1          https://api.github.com/users/WindSoilder
# 2               https://api.github.com/users/Moisan
# 3          https://api.github.com/users/WindSoilder
# 4           https://api.github.com/users/topper-123
# 5           https://api.github.com/users/lukemanley
# 6             https://api.github.com/users/Th3nn3ss
# 7           https://api.github.com/users/ramvikrams
# 8             https://api.github.com/users/Th3nn3ss
# 9                https://api.github.com/users/csala
# 10        https://api.github.com/users/jbrockmendel
# 11          https://api.github.com/users/rhshadrach
# 12               https://api.github.com/users/phofl
# 13               https://api.github.com/users/phofl
# 14        https://api.github.com/users/jbrockmendel
# 15          https://api.github.com/users/rhshadrach
# 16        https://api.github.com/users/jbrockmendel
# 17          https://api.github.com/users/topper-123
# 18          https://api.github.com/users/topper-123
# 19          https://api.github.com/users/topper-123
# 20   https://api.github.com/users/thlautenschlaeger
# 21            https://api.github.com/users/cdcadman
# 22        https://api.github.com/users/jbrockmendel
# 23            https://api.github.com/users/noritada
# 24        https://api.github.com/users/arnaudlegout
# 25  https://api.github.com/users/jorisvandenbossche
# 26  https://api.github.com/users/jorisvandenbossche
# 27             https://api.github.com/users/anbjork
# 28  https://api.github.com/users/jorisvandenbossche
# 29                 https://api.github.com/users/akx
# 30           https://api.github.com/users/david6l34
# 31            https://api.github.com/users/it176131
#
#                                  html_url  \
# 0               https://github.com/Moisan
# 1          https://github.com/WindSoilder
# 2               https://github.com/Moisan
# 3          https://github.com/WindSoilder
# 4           https://github.com/topper-123
# 5           https://github.com/lukemanley
# 6             https://github.com/Th3nn3ss
# 7           https://github.com/ramvikrams
# 8             https://github.com/Th3nn3ss
# 9                https://github.com/csala
# 10        https://github.com/jbrockmendel
# 11          https://github.com/rhshadrach
# 12               https://github.com/phofl
# 13               https://github.com/phofl
# 14        https://github.com/jbrockmendel
# 15          https://github.com/rhshadrach
# 16        https://github.com/jbrockmendel
# 17          https://github.com/topper-123
# 18          https://github.com/topper-123
# 19          https://github.com/topper-123
# 20   https://github.com/thlautenschlaeger
# 21            https://github.com/cdcadman
# 22        https://github.com/jbrockmendel
# 23            https://github.com/noritada
# 24        https://github.com/arnaudlegout
# 25  https://github.com/jorisvandenbossche
# 26  https://github.com/jorisvandenbossche
# 27             https://github.com/anbjork
# 28  https://github.com/jorisvandenbossche
# 29                 https://github.com/akx
# 30           https://github.com/david6l34
# 31            https://github.com/it176131
#
#                                         followers_url  \
# 0       https://api.github.com/users/Moisan/followers
# 1   https://api.github.com/users/WindSoilder/follo...
# 2       https://api.github.com/users/Moisan/followers
# 3   https://api.github.com/users/WindSoilder/follo...
# 4   https://api.github.com/users/topper-123/followers
# 5   https://api.github.com/users/lukemanley/followers
# 6     https://api.github.com/users/Th3nn3ss/followers
# 7   https://api.github.com/users/ramvikrams/followers
# 8     https://api.github.com/users/Th3nn3ss/followers
# 9        https://api.github.com/users/csala/followers
# 10  https://api.github.com/users/jbrockmendel/foll...
# 11  https://api.github.com/users/rhshadrach/followers
# 12       https://api.github.com/users/phofl/followers
# 13       https://api.github.com/users/phofl/followers
# 14  https://api.github.com/users/jbrockmendel/foll...
# 15  https://api.github.com/users/rhshadrach/followers
# 16  https://api.github.com/users/jbrockmendel/foll...
# 17  https://api.github.com/users/topper-123/followers
# 18  https://api.github.com/users/topper-123/followers
# 19  https://api.github.com/users/topper-123/followers
# 20  https://api.github.com/users/thlautenschlaeger...
# 21    https://api.github.com/users/cdcadman/followers
# 22  https://api.github.com/users/jbrockmendel/foll...
# 23    https://api.github.com/users/noritada/followers
# 24  https://api.github.com/users/arnaudlegout/foll...
# 25  https://api.github.com/users/jorisvandenbossch...
# 26  https://api.github.com/users/jorisvandenbossch...
# 27     https://api.github.com/users/anbjork/followers
# 28  https://api.github.com/users/jorisvandenbossch...
# 29         https://api.github.com/users/akx/followers
# 30   https://api.github.com/users/david6l34/followers
# 31    https://api.github.com/users/it176131/followers
#
#                                         following_url  \
# 0   https://api.github.com/users/Moisan/following{...
# 1   https://api.github.com/users/WindSoilder/follo...
# 2   https://api.github.com/users/Moisan/following{...
# 3   https://api.github.com/users/WindSoilder/follo...
# 4   https://api.github.com/users/topper-123/follow...
# 5   https://api.github.com/users/lukemanley/follow...
# 6   https://api.github.com/users/Th3nn3ss/followin...
# 7   https://api.github.com/users/ramvikrams/follow...
# 8   https://api.github.com/users/Th3nn3ss/followin...
# 9   https://api.github.com/users/csala/following{/...
# 10  https://api.github.com/users/jbrockmendel/foll...
# 11  https://api.github.com/users/rhshadrach/follow...
# 12  https://api.github.com/users/phofl/following{/...
# 13  https://api.github.com/users/phofl/following{/...
# 14  https://api.github.com/users/jbrockmendel/foll...
# 15  https://api.github.com/users/rhshadrach/follow...
# 16  https://api.github.com/users/jbrockmendel/foll...
# 17  https://api.github.com/users/topper-123/follow...
# 18  https://api.github.com/users/topper-123/follow...
# 19  https://api.github.com/users/topper-123/follow...
# 20  https://api.github.com/users/thlautenschlaeger...
# 21  https://api.github.com/users/cdcadman/followin...
# 22  https://api.github.com/users/jbrockmendel/foll...
# 23  https://api.github.com/users/noritada/followin...
# 24  https://api.github.com/users/arnaudlegout/foll...
# 25  https://api.github.com/users/jorisvandenbossch...
# 26  https://api.github.com/users/jorisvandenbossch...
# 27  https://api.github.com/users/anbjork/following...
# 28  https://api.github.com/users/jorisvandenbossch...
# 29  https://api.github.com/users/akx/following{/ot...
# 30  https://api.github.com/users/david6l34/followi...
# 31  https://api.github.com/users/it176131/followin...
#
#                                             gists_url  \
# 0   https://api.github.com/users/Moisan/gists{/gis...
# 1   https://api.github.com/users/WindSoilder/gists...
# 2   https://api.github.com/users/Moisan/gists{/gis...
# 3   https://api.github.com/users/WindSoilder/gists...
# 4   https://api.github.com/users/topper-123/gists{...
# 5   https://api.github.com/users/lukemanley/gists{...
# 6   https://api.github.com/users/Th3nn3ss/gists{/g...
# 7   https://api.github.com/users/ramvikrams/gists{...
# 8   https://api.github.com/users/Th3nn3ss/gists{/g...
# 9   https://api.github.com/users/csala/gists{/gist...
# 10  https://api.github.com/users/jbrockmendel/gist...
# 11  https://api.github.com/users/rhshadrach/gists{...
# 12  https://api.github.com/users/phofl/gists{/gist...
# 13  https://api.github.com/users/phofl/gists{/gist...
# 14  https://api.github.com/users/jbrockmendel/gist...
# 15  https://api.github.com/users/rhshadrach/gists{...
# 16  https://api.github.com/users/jbrockmendel/gist...
# 17  https://api.github.com/users/topper-123/gists{...
# 18  https://api.github.com/users/topper-123/gists{...
# 19  https://api.github.com/users/topper-123/gists{...
# 20  https://api.github.com/users/thlautenschlaeger...
# 21  https://api.github.com/users/cdcadman/gists{/g...
# 22  https://api.github.com/users/jbrockmendel/gist...
# 23  https://api.github.com/users/noritada/gists{/g...
# 24  https://api.github.com/users/arnaudlegout/gist...
# 25  https://api.github.com/users/jorisvandenbossch...
# 26  https://api.github.com/users/jorisvandenbossch...
# 27  https://api.github.com/users/anbjork/gists{/gi...
# 28  https://api.github.com/users/jorisvandenbossch...
# 29   https://api.github.com/users/akx/gists{/gist_id}
# 30  https://api.github.com/users/david6l34/gists{/...
# 31  https://api.github.com/users/it176131/gists{/g...
#
#                                           starred_url  \
# 0   https://api.github.com/users/Moisan/starred{/o...
# 1   https://api.github.com/users/WindSoilder/starr...
# 2   https://api.github.com/users/Moisan/starred{/o...
# 3   https://api.github.com/users/WindSoilder/starr...
# 4   https://api.github.com/users/topper-123/starre...
# 5   https://api.github.com/users/lukemanley/starre...
# 6   https://api.github.com/users/Th3nn3ss/starred{...
# 7   https://api.github.com/users/ramvikrams/starre...
# 8   https://api.github.com/users/Th3nn3ss/starred{...
# 9   https://api.github.com/users/csala/starred{/ow...
# 10  https://api.github.com/users/jbrockmendel/star...
# 11  https://api.github.com/users/rhshadrach/starre...
# 12  https://api.github.com/users/phofl/starred{/ow...
# 13  https://api.github.com/users/phofl/starred{/ow...
# 14  https://api.github.com/users/jbrockmendel/star...
# 15  https://api.github.com/users/rhshadrach/starre...
# 16  https://api.github.com/users/jbrockmendel/star...
# 17  https://api.github.com/users/topper-123/starre...
# 18  https://api.github.com/users/topper-123/starre...
# 19  https://api.github.com/users/topper-123/starre...
# 20  https://api.github.com/users/thlautenschlaeger...
# 21  https://api.github.com/users/cdcadman/starred{...
# 22  https://api.github.com/users/jbrockmendel/star...
# 23  https://api.github.com/users/noritada/starred{...
# 24  https://api.github.com/users/arnaudlegout/star...
# 25  https://api.github.com/users/jorisvandenbossch...
# 26  https://api.github.com/users/jorisvandenbossch...
# 27  https://api.github.com/users/anbjork/starred{/...
# 28  https://api.github.com/users/jorisvandenbossch...
# 29  https://api.github.com/users/akx/starred{/owne...
# 30  https://api.github.com/users/david6l34/starred...
# 31  https://api.github.com/users/it176131/starred{...
#
#                                     subscriptions_url  \
# 0   https://api.github.com/users/Moisan/subscriptions
# 1   https://api.github.com/users/WindSoilder/subsc...
# 2   https://api.github.com/users/Moisan/subscriptions
# 3   https://api.github.com/users/WindSoilder/subsc...
# 4   https://api.github.com/users/topper-123/subscr...
# 5   https://api.github.com/users/lukemanley/subscr...
# 6   https://api.github.com/users/Th3nn3ss/subscrip...
# 7   https://api.github.com/users/ramvikrams/subscr...
# 8   https://api.github.com/users/Th3nn3ss/subscrip...
# 9    https://api.github.com/users/csala/subscriptions
# 10  https://api.github.com/users/jbrockmendel/subs...
# 11  https://api.github.com/users/rhshadrach/subscr...
# 12   https://api.github.com/users/phofl/subscriptions
# 13   https://api.github.com/users/phofl/subscriptions
# 14  https://api.github.com/users/jbrockmendel/subs...
# 15  https://api.github.com/users/rhshadrach/subscr...
# 16  https://api.github.com/users/jbrockmendel/subs...
# 17  https://api.github.com/users/topper-123/subscr...
# 18  https://api.github.com/users/topper-123/subscr...
# 19  https://api.github.com/users/topper-123/subscr...
# 20  https://api.github.com/users/thlautenschlaeger...
# 21  https://api.github.com/users/cdcadman/subscrip...
# 22  https://api.github.com/users/jbrockmendel/subs...
# 23  https://api.github.com/users/noritada/subscrip...
# 24  https://api.github.com/users/arnaudlegout/subs...
# 25  https://api.github.com/users/jorisvandenbossch...
# 26  https://api.github.com/users/jorisvandenbossch...
# 27  https://api.github.com/users/anbjork/subscript...
# 28  https://api.github.com/users/jorisvandenbossch...
# 29     https://api.github.com/users/akx/subscriptions
# 30  https://api.github.com/users/david6l34/subscri...
# 31  https://api.github.com/users/it176131/subscrip...
#
#                                     organizations_url  \
# 0            https://api.github.com/users/Moisan/orgs
# 1       https://api.github.com/users/WindSoilder/orgs
# 2            https://api.github.com/users/Moisan/orgs
# 3       https://api.github.com/users/WindSoilder/orgs
# 4        https://api.github.com/users/topper-123/orgs
# 5        https://api.github.com/users/lukemanley/orgs
# 6          https://api.github.com/users/Th3nn3ss/orgs
# 7        https://api.github.com/users/ramvikrams/orgs
# 8          https://api.github.com/users/Th3nn3ss/orgs
# 9             https://api.github.com/users/csala/orgs
# 10     https://api.github.com/users/jbrockmendel/orgs
# 11       https://api.github.com/users/rhshadrach/orgs
# 12            https://api.github.com/users/phofl/orgs
# 13            https://api.github.com/users/phofl/orgs
# 14     https://api.github.com/users/jbrockmendel/orgs
# 15       https://api.github.com/users/rhshadrach/orgs
# 16     https://api.github.com/users/jbrockmendel/orgs
# 17       https://api.github.com/users/topper-123/orgs
# 18       https://api.github.com/users/topper-123/orgs
# 19       https://api.github.com/users/topper-123/orgs
# 20  https://api.github.com/users/thlautenschlaeger...
# 21         https://api.github.com/users/cdcadman/orgs
# 22     https://api.github.com/users/jbrockmendel/orgs
# 23         https://api.github.com/users/noritada/orgs
# 24     https://api.github.com/users/arnaudlegout/orgs
# 25  https://api.github.com/users/jorisvandenbossch...
# 26  https://api.github.com/users/jorisvandenbossch...
# 27          https://api.github.com/users/anbjork/orgs
# 28  https://api.github.com/users/jorisvandenbossch...
# 29              https://api.github.com/users/akx/orgs
# 30        https://api.github.com/users/david6l34/orgs
# 31         https://api.github.com/users/it176131/orgs
#
#                                             repos_url  \
# 0           https://api.github.com/users/Moisan/repos
# 1      https://api.github.com/users/WindSoilder/repos
# 2           https://api.github.com/users/Moisan/repos
# 3      https://api.github.com/users/WindSoilder/repos
# 4       https://api.github.com/users/topper-123/repos
# 5       https://api.github.com/users/lukemanley/repos
# 6         https://api.github.com/users/Th3nn3ss/repos
# 7       https://api.github.com/users/ramvikrams/repos
# 8         https://api.github.com/users/Th3nn3ss/repos
# 9            https://api.github.com/users/csala/repos
# 10    https://api.github.com/users/jbrockmendel/repos
# 11      https://api.github.com/users/rhshadrach/repos
# 12           https://api.github.com/users/phofl/repos
# 13           https://api.github.com/users/phofl/repos
# 14    https://api.github.com/users/jbrockmendel/repos
# 15      https://api.github.com/users/rhshadrach/repos
# 16    https://api.github.com/users/jbrockmendel/repos
# 17      https://api.github.com/users/topper-123/repos
# 18      https://api.github.com/users/topper-123/repos
# 19      https://api.github.com/users/topper-123/repos
# 20  https://api.github.com/users/thlautenschlaeger...
# 21        https://api.github.com/users/cdcadman/repos
# 22    https://api.github.com/users/jbrockmendel/repos
# 23        https://api.github.com/users/noritada/repos
# 24    https://api.github.com/users/arnaudlegout/repos
# 25  https://api.github.com/users/jorisvandenbossch...
# 26  https://api.github.com/users/jorisvandenbossch...
# 27         https://api.github.com/users/anbjork/repos
# 28  https://api.github.com/users/jorisvandenbossch...
# 29             https://api.github.com/users/akx/repos
# 30       https://api.github.com/users/david6l34/repos
# 31        https://api.github.com/users/it176131/repos
#
#                                            events_url  \
# 0   https://api.github.com/users/Moisan/events{/pr...
# 1   https://api.github.com/users/WindSoilder/event...
# 2   https://api.github.com/users/Moisan/events{/pr...
# 3   https://api.github.com/users/WindSoilder/event...
# 4   https://api.github.com/users/topper-123/events...
# 5   https://api.github.com/users/lukemanley/events...
# 6   https://api.github.com/users/Th3nn3ss/events{/...
# 7   https://api.github.com/users/ramvikrams/events...
# 8   https://api.github.com/users/Th3nn3ss/events{/...
# 9   https://api.github.com/users/csala/events{/pri...
# 10  https://api.github.com/users/jbrockmendel/even...
# 11  https://api.github.com/users/rhshadrach/events...
# 12  https://api.github.com/users/phofl/events{/pri...
# 13  https://api.github.com/users/phofl/events{/pri...
# 14  https://api.github.com/users/jbrockmendel/even...
# 15  https://api.github.com/users/rhshadrach/events...
# 16  https://api.github.com/users/jbrockmendel/even...
# 17  https://api.github.com/users/topper-123/events...
# 18  https://api.github.com/users/topper-123/events...
# 19  https://api.github.com/users/topper-123/events...
# 20  https://api.github.com/users/thlautenschlaeger...
# 21  https://api.github.com/users/cdcadman/events{/...
# 22  https://api.github.com/users/jbrockmendel/even...
# 23  https://api.github.com/users/noritada/events{/...
# 24  https://api.github.com/users/arnaudlegout/even...
# 25  https://api.github.com/users/jorisvandenbossch...
# 26  https://api.github.com/users/jorisvandenbossch...
# 27  https://api.github.com/users/anbjork/events{/p...
# 28  https://api.github.com/users/jorisvandenbossch...
# 29  https://api.github.com/users/akx/events{/privacy}
# 30  https://api.github.com/users/david6l34/events{...
# 31  https://api.github.com/users/it176131/events{/...
#
#                                   received_events_url  type  site_admin
# 0   https://api.github.com/users/Moisan/received_e...  User       False
# 1   https://api.github.com/users/WindSoilder/recei...  User       False
# 2   https://api.github.com/users/Moisan/received_e...  User       False
# 3   https://api.github.com/users/WindSoilder/recei...  User       False
# 4   https://api.github.com/users/topper-123/receiv...  User       False
# 5   https://api.github.com/users/lukemanley/receiv...  User       False
# 6   https://api.github.com/users/Th3nn3ss/received...  User       False
# 7   https://api.github.com/users/ramvikrams/receiv...  User       False
# 8   https://api.github.com/users/Th3nn3ss/received...  User       False
# 9   https://api.github.com/users/csala/received_ev...  User       False
# 10  https://api.github.com/users/jbrockmendel/rece...  User       False
# 11  https://api.github.com/users/rhshadrach/receiv...  User       False
# 12  https://api.github.com/users/phofl/received_ev...  User       False
# 13  https://api.github.com/users/phofl/received_ev...  User       False
# 14  https://api.github.com/users/jbrockmendel/rece...  User       False
# 15  https://api.github.com/users/rhshadrach/receiv...  User       False
# 16  https://api.github.com/users/jbrockmendel/rece...  User       False
# 17  https://api.github.com/users/topper-123/receiv...  User       False
# 18  https://api.github.com/users/topper-123/receiv...  User       False
# 19  https://api.github.com/users/topper-123/receiv...  User       False
# 20  https://api.github.com/users/thlautenschlaeger...  User       False
# 21  https://api.github.com/users/cdcadman/received...  User       False
# 22  https://api.github.com/users/jbrockmendel/rece...  User       False
# 23  https://api.github.com/users/noritada/received...  User       False
# 24  https://api.github.com/users/arnaudlegout/rece...  User       False
# 25  https://api.github.com/users/jorisvandenbossch...  User       False
# 26  https://api.github.com/users/jorisvandenbossch...  User       False
# 27  https://api.github.com/users/anbjork/received_...  User       False
# 28  https://api.github.com/users/jorisvandenbossch...  User       False
# 29   https://api.github.com/users/akx/received_events  User       False
# 30  https://api.github.com/users/david6l34/receive...  User       False
# 31  https://api.github.com/users/it176131/received...  User       False

# %%
pd.DataFrame(lis).to_csv("user1.csv")

# %%
pd.read_csv('user1.csv')
# Out:
#     Unnamed: 0               login         id               node_id  \
# 0            0              Moisan      31669      MDQ6VXNlcjMxNjY5
# 1            1         WindSoilder   22256154  MDQ6VXNlcjIyMjU2MTU0
# 2            2              Moisan      31669      MDQ6VXNlcjMxNjY5
# 3            3         WindSoilder   22256154  MDQ6VXNlcjIyMjU2MTU0
# 4            4          topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 5            5          lukemanley    8519523  MDQ6VXNlcjg1MTk1MjM=
# 6            6            Th3nn3ss   25160953  MDQ6VXNlcjI1MTYwOTUz
# 7            7          ramvikrams  106332857          U_kgDOBlaCuQ
# 8            8            Th3nn3ss   25160953  MDQ6VXNlcjI1MTYwOTUz
# 9            9               csala    6129283  MDQ6VXNlcjYxMjkyODM=
# 10          10        jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 11          11          rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 12          12               phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 13          13               phofl   61934744  MDQ6VXNlcjYxOTM0NzQ0
# 14          14        jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 15          15          rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 16          16        jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 17          17          topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 18          18          topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 19          19          topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 20          20   thlautenschlaeger   33692555  MDQ6VXNlcjMzNjkyNTU1
# 21          21            cdcadman   51368516  MDQ6VXNlcjUxMzY4NTE2
# 22          22        jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 23          23            noritada      20850      MDQ6VXNlcjIwODUw
# 24          24        arnaudlegout    7670869  MDQ6VXNlcjc2NzA4Njk=
# 25          25  jorisvandenbossche    1020496  MDQ6VXNlcjEwMjA0OTY=
# 26          26  jorisvandenbossche    1020496  MDQ6VXNlcjEwMjA0OTY=
# 27          27             anbjork   37732575  MDQ6VXNlcjM3NzMyNTc1
# 28          28  jorisvandenbossche    1020496  MDQ6VXNlcjEwMjA0OTY=
# 29          29                 akx      58669      MDQ6VXNlcjU4NjY5
# 30          30           david6l34   55838817  MDQ6VXNlcjU1ODM4ODE3
# 31          31            it176131   13686957  MDQ6VXNlcjEzNjg2OTU3
#
#                                            avatar_url  gravatar_id  \
# 0   https://avatars.githubusercontent.com/u/31669?v=4          NaN
# 1   https://avatars.githubusercontent.com/u/222561...          NaN
# 2   https://avatars.githubusercontent.com/u/31669?v=4          NaN
# 3   https://avatars.githubusercontent.com/u/222561...          NaN
# 4   https://avatars.githubusercontent.com/u/263644...          NaN
# 5   https://avatars.githubusercontent.com/u/851952...          NaN
# 6   https://avatars.githubusercontent.com/u/251609...          NaN
# 7   https://avatars.githubusercontent.com/u/106332...          NaN
# 8   https://avatars.githubusercontent.com/u/251609...          NaN
# 9   https://avatars.githubusercontent.com/u/612928...          NaN
# 10  https://avatars.githubusercontent.com/u/807896...          NaN
# 11  https://avatars.githubusercontent.com/u/455624...          NaN
# 12  https://avatars.githubusercontent.com/u/619347...          NaN
# 13  https://avatars.githubusercontent.com/u/619347...          NaN
# 14  https://avatars.githubusercontent.com/u/807896...          NaN
# 15  https://avatars.githubusercontent.com/u/455624...          NaN
# 16  https://avatars.githubusercontent.com/u/807896...          NaN
# 17  https://avatars.githubusercontent.com/u/263644...          NaN
# 18  https://avatars.githubusercontent.com/u/263644...          NaN
# 19  https://avatars.githubusercontent.com/u/263644...          NaN
# 20  https://avatars.githubusercontent.com/u/336925...          NaN
# 21  https://avatars.githubusercontent.com/u/513685...          NaN
# 22  https://avatars.githubusercontent.com/u/807896...          NaN
# 23  https://avatars.githubusercontent.com/u/20850?v=4          NaN
# 24  https://avatars.githubusercontent.com/u/767086...          NaN
# 25  https://avatars.githubusercontent.com/u/102049...          NaN
# 26  https://avatars.githubusercontent.com/u/102049...          NaN
# 27  https://avatars.githubusercontent.com/u/377325...          NaN
# 28  https://avatars.githubusercontent.com/u/102049...          NaN
# 29  https://avatars.githubusercontent.com/u/58669?v=4          NaN
# 30  https://avatars.githubusercontent.com/u/558388...          NaN
# 31  https://avatars.githubusercontent.com/u/136869...          NaN
#
#                                                 url  \
# 0               https://api.github.com/users/Moisan
# 1          https://api.github.com/users/WindSoilder
# 2               https://api.github.com/users/Moisan
# 3          https://api.github.com/users/WindSoilder
# 4           https://api.github.com/users/topper-123
# 5           https://api.github.com/users/lukemanley
# 6             https://api.github.com/users/Th3nn3ss
# 7           https://api.github.com/users/ramvikrams
# 8             https://api.github.com/users/Th3nn3ss
# 9                https://api.github.com/users/csala
# 10        https://api.github.com/users/jbrockmendel
# 11          https://api.github.com/users/rhshadrach
# 12               https://api.github.com/users/phofl
# 13               https://api.github.com/users/phofl
# 14        https://api.github.com/users/jbrockmendel
# 15          https://api.github.com/users/rhshadrach
# 16        https://api.github.com/users/jbrockmendel
# 17          https://api.github.com/users/topper-123
# 18          https://api.github.com/users/topper-123
# 19          https://api.github.com/users/topper-123
# 20   https://api.github.com/users/thlautenschlaeger
# 21            https://api.github.com/users/cdcadman
# 22        https://api.github.com/users/jbrockmendel
# 23            https://api.github.com/users/noritada
# 24        https://api.github.com/users/arnaudlegout
# 25  https://api.github.com/users/jorisvandenbossche
# 26  https://api.github.com/users/jorisvandenbossche
# 27             https://api.github.com/users/anbjork
# 28  https://api.github.com/users/jorisvandenbossche
# 29                 https://api.github.com/users/akx
# 30           https://api.github.com/users/david6l34
# 31            https://api.github.com/users/it176131
#
#                                  html_url  \
# 0               https://github.com/Moisan
# 1          https://github.com/WindSoilder
# 2               https://github.com/Moisan
# 3          https://github.com/WindSoilder
# 4           https://github.com/topper-123
# 5           https://github.com/lukemanley
# 6             https://github.com/Th3nn3ss
# 7           https://github.com/ramvikrams
# 8             https://github.com/Th3nn3ss
# 9                https://github.com/csala
# 10        https://github.com/jbrockmendel
# 11          https://github.com/rhshadrach
# 12               https://github.com/phofl
# 13               https://github.com/phofl
# 14        https://github.com/jbrockmendel
# 15          https://github.com/rhshadrach
# 16        https://github.com/jbrockmendel
# 17          https://github.com/topper-123
# 18          https://github.com/topper-123
# 19          https://github.com/topper-123
# 20   https://github.com/thlautenschlaeger
# 21            https://github.com/cdcadman
# 22        https://github.com/jbrockmendel
# 23            https://github.com/noritada
# 24        https://github.com/arnaudlegout
# 25  https://github.com/jorisvandenbossche
# 26  https://github.com/jorisvandenbossche
# 27             https://github.com/anbjork
# 28  https://github.com/jorisvandenbossche
# 29                 https://github.com/akx
# 30           https://github.com/david6l34
# 31            https://github.com/it176131
#
#                                         followers_url  \
# 0       https://api.github.com/users/Moisan/followers
# 1   https://api.github.com/users/WindSoilder/follo...
# 2       https://api.github.com/users/Moisan/followers
# 3   https://api.github.com/users/WindSoilder/follo...
# 4   https://api.github.com/users/topper-123/followers
# 5   https://api.github.com/users/lukemanley/followers
# 6     https://api.github.com/users/Th3nn3ss/followers
# 7   https://api.github.com/users/ramvikrams/followers
# 8     https://api.github.com/users/Th3nn3ss/followers
# 9        https://api.github.com/users/csala/followers
# 10  https://api.github.com/users/jbrockmendel/foll...
# 11  https://api.github.com/users/rhshadrach/followers
# 12       https://api.github.com/users/phofl/followers
# 13       https://api.github.com/users/phofl/followers
# 14  https://api.github.com/users/jbrockmendel/foll...
# 15  https://api.github.com/users/rhshadrach/followers
# 16  https://api.github.com/users/jbrockmendel/foll...
# 17  https://api.github.com/users/topper-123/followers
# 18  https://api.github.com/users/topper-123/followers
# 19  https://api.github.com/users/topper-123/followers
# 20  https://api.github.com/users/thlautenschlaeger...
# 21    https://api.github.com/users/cdcadman/followers
# 22  https://api.github.com/users/jbrockmendel/foll...
# 23    https://api.github.com/users/noritada/followers
# 24  https://api.github.com/users/arnaudlegout/foll...
# 25  https://api.github.com/users/jorisvandenbossch...
# 26  https://api.github.com/users/jorisvandenbossch...
# 27     https://api.github.com/users/anbjork/followers
# 28  https://api.github.com/users/jorisvandenbossch...
# 29         https://api.github.com/users/akx/followers
# 30   https://api.github.com/users/david6l34/followers
# 31    https://api.github.com/users/it176131/followers
#
#                                         following_url  \
# 0   https://api.github.com/users/Moisan/following{...
# 1   https://api.github.com/users/WindSoilder/follo...
# 2   https://api.github.com/users/Moisan/following{...
# 3   https://api.github.com/users/WindSoilder/follo...
# 4   https://api.github.com/users/topper-123/follow...
# 5   https://api.github.com/users/lukemanley/follow...
# 6   https://api.github.com/users/Th3nn3ss/followin...
# 7   https://api.github.com/users/ramvikrams/follow...
# 8   https://api.github.com/users/Th3nn3ss/followin...
# 9   https://api.github.com/users/csala/following{/...
# 10  https://api.github.com/users/jbrockmendel/foll...
# 11  https://api.github.com/users/rhshadrach/follow...
# 12  https://api.github.com/users/phofl/following{/...
# 13  https://api.github.com/users/phofl/following{/...
# 14  https://api.github.com/users/jbrockmendel/foll...
# 15  https://api.github.com/users/rhshadrach/follow...
# 16  https://api.github.com/users/jbrockmendel/foll...
# 17  https://api.github.com/users/topper-123/follow...
# 18  https://api.github.com/users/topper-123/follow...
# 19  https://api.github.com/users/topper-123/follow...
# 20  https://api.github.com/users/thlautenschlaeger...
# 21  https://api.github.com/users/cdcadman/followin...
# 22  https://api.github.com/users/jbrockmendel/foll...
# 23  https://api.github.com/users/noritada/followin...
# 24  https://api.github.com/users/arnaudlegout/foll...
# 25  https://api.github.com/users/jorisvandenbossch...
# 26  https://api.github.com/users/jorisvandenbossch...
# 27  https://api.github.com/users/anbjork/following...
# 28  https://api.github.com/users/jorisvandenbossch...
# 29  https://api.github.com/users/akx/following{/ot...
# 30  https://api.github.com/users/david6l34/followi...
# 31  https://api.github.com/users/it176131/followin...
#
#                                             gists_url  \
# 0   https://api.github.com/users/Moisan/gists{/gis...
# 1   https://api.github.com/users/WindSoilder/gists...
# 2   https://api.github.com/users/Moisan/gists{/gis...
# 3   https://api.github.com/users/WindSoilder/gists...
# 4   https://api.github.com/users/topper-123/gists{...
# 5   https://api.github.com/users/lukemanley/gists{...
# 6   https://api.github.com/users/Th3nn3ss/gists{/g...
# 7   https://api.github.com/users/ramvikrams/gists{...
# 8   https://api.github.com/users/Th3nn3ss/gists{/g...
# 9   https://api.github.com/users/csala/gists{/gist...
# 10  https://api.github.com/users/jbrockmendel/gist...
# 11  https://api.github.com/users/rhshadrach/gists{...
# 12  https://api.github.com/users/phofl/gists{/gist...
# 13  https://api.github.com/users/phofl/gists{/gist...
# 14  https://api.github.com/users/jbrockmendel/gist...
# 15  https://api.github.com/users/rhshadrach/gists{...
# 16  https://api.github.com/users/jbrockmendel/gist...
# 17  https://api.github.com/users/topper-123/gists{...
# 18  https://api.github.com/users/topper-123/gists{...
# 19  https://api.github.com/users/topper-123/gists{...
# 20  https://api.github.com/users/thlautenschlaeger...
# 21  https://api.github.com/users/cdcadman/gists{/g...
# 22  https://api.github.com/users/jbrockmendel/gist...
# 23  https://api.github.com/users/noritada/gists{/g...
# 24  https://api.github.com/users/arnaudlegout/gist...
# 25  https://api.github.com/users/jorisvandenbossch...
# 26  https://api.github.com/users/jorisvandenbossch...
# 27  https://api.github.com/users/anbjork/gists{/gi...
# 28  https://api.github.com/users/jorisvandenbossch...
# 29   https://api.github.com/users/akx/gists{/gist_id}
# 30  https://api.github.com/users/david6l34/gists{/...
# 31  https://api.github.com/users/it176131/gists{/g...
#
#                                           starred_url  \
# 0   https://api.github.com/users/Moisan/starred{/o...
# 1   https://api.github.com/users/WindSoilder/starr...
# 2   https://api.github.com/users/Moisan/starred{/o...
# 3   https://api.github.com/users/WindSoilder/starr...
# 4   https://api.github.com/users/topper-123/starre...
# 5   https://api.github.com/users/lukemanley/starre...
# 6   https://api.github.com/users/Th3nn3ss/starred{...
# 7   https://api.github.com/users/ramvikrams/starre...
# 8   https://api.github.com/users/Th3nn3ss/starred{...
# 9   https://api.github.com/users/csala/starred{/ow...
# 10  https://api.github.com/users/jbrockmendel/star...
# 11  https://api.github.com/users/rhshadrach/starre...
# 12  https://api.github.com/users/phofl/starred{/ow...
# 13  https://api.github.com/users/phofl/starred{/ow...
# 14  https://api.github.com/users/jbrockmendel/star...
# 15  https://api.github.com/users/rhshadrach/starre...
# 16  https://api.github.com/users/jbrockmendel/star...
# 17  https://api.github.com/users/topper-123/starre...
# 18  https://api.github.com/users/topper-123/starre...
# 19  https://api.github.com/users/topper-123/starre...
# 20  https://api.github.com/users/thlautenschlaeger...
# 21  https://api.github.com/users/cdcadman/starred{...
# 22  https://api.github.com/users/jbrockmendel/star...
# 23  https://api.github.com/users/noritada/starred{...
# 24  https://api.github.com/users/arnaudlegout/star...
# 25  https://api.github.com/users/jorisvandenbossch...
# 26  https://api.github.com/users/jorisvandenbossch...
# 27  https://api.github.com/users/anbjork/starred{/...
# 28  https://api.github.com/users/jorisvandenbossch...
# 29  https://api.github.com/users/akx/starred{/owne...
# 30  https://api.github.com/users/david6l34/starred...
# 31  https://api.github.com/users/it176131/starred{...
#
#                                     subscriptions_url  \
# 0   https://api.github.com/users/Moisan/subscriptions
# 1   https://api.github.com/users/WindSoilder/subsc...
# 2   https://api.github.com/users/Moisan/subscriptions
# 3   https://api.github.com/users/WindSoilder/subsc...
# 4   https://api.github.com/users/topper-123/subscr...
# 5   https://api.github.com/users/lukemanley/subscr...
# 6   https://api.github.com/users/Th3nn3ss/subscrip...
# 7   https://api.github.com/users/ramvikrams/subscr...
# 8   https://api.github.com/users/Th3nn3ss/subscrip...
# 9    https://api.github.com/users/csala/subscriptions
# 10  https://api.github.com/users/jbrockmendel/subs...
# 11  https://api.github.com/users/rhshadrach/subscr...
# 12   https://api.github.com/users/phofl/subscriptions
# 13   https://api.github.com/users/phofl/subscriptions
# 14  https://api.github.com/users/jbrockmendel/subs...
# 15  https://api.github.com/users/rhshadrach/subscr...
# 16  https://api.github.com/users/jbrockmendel/subs...
# 17  https://api.github.com/users/topper-123/subscr...
# 18  https://api.github.com/users/topper-123/subscr...
# 19  https://api.github.com/users/topper-123/subscr...
# 20  https://api.github.com/users/thlautenschlaeger...
# 21  https://api.github.com/users/cdcadman/subscrip...
# 22  https://api.github.com/users/jbrockmendel/subs...
# 23  https://api.github.com/users/noritada/subscrip...
# 24  https://api.github.com/users/arnaudlegout/subs...
# 25  https://api.github.com/users/jorisvandenbossch...
# 26  https://api.github.com/users/jorisvandenbossch...
# 27  https://api.github.com/users/anbjork/subscript...
# 28  https://api.github.com/users/jorisvandenbossch...
# 29     https://api.github.com/users/akx/subscriptions
# 30  https://api.github.com/users/david6l34/subscri...
# 31  https://api.github.com/users/it176131/subscrip...
#
#                                     organizations_url  \
# 0            https://api.github.com/users/Moisan/orgs
# 1       https://api.github.com/users/WindSoilder/orgs
# 2            https://api.github.com/users/Moisan/orgs
# 3       https://api.github.com/users/WindSoilder/orgs
# 4        https://api.github.com/users/topper-123/orgs
# 5        https://api.github.com/users/lukemanley/orgs
# 6          https://api.github.com/users/Th3nn3ss/orgs
# 7        https://api.github.com/users/ramvikrams/orgs
# 8          https://api.github.com/users/Th3nn3ss/orgs
# 9             https://api.github.com/users/csala/orgs
# 10     https://api.github.com/users/jbrockmendel/orgs
# 11       https://api.github.com/users/rhshadrach/orgs
# 12            https://api.github.com/users/phofl/orgs
# 13            https://api.github.com/users/phofl/orgs
# 14     https://api.github.com/users/jbrockmendel/orgs
# 15       https://api.github.com/users/rhshadrach/orgs
# 16     https://api.github.com/users/jbrockmendel/orgs
# 17       https://api.github.com/users/topper-123/orgs
# 18       https://api.github.com/users/topper-123/orgs
# 19       https://api.github.com/users/topper-123/orgs
# 20  https://api.github.com/users/thlautenschlaeger...
# 21         https://api.github.com/users/cdcadman/orgs
# 22     https://api.github.com/users/jbrockmendel/orgs
# 23         https://api.github.com/users/noritada/orgs
# 24     https://api.github.com/users/arnaudlegout/orgs
# 25  https://api.github.com/users/jorisvandenbossch...
# 26  https://api.github.com/users/jorisvandenbossch...
# 27          https://api.github.com/users/anbjork/orgs
# 28  https://api.github.com/users/jorisvandenbossch...
# 29              https://api.github.com/users/akx/orgs
# 30        https://api.github.com/users/david6l34/orgs
# 31         https://api.github.com/users/it176131/orgs
#
#                                             repos_url  \
# 0           https://api.github.com/users/Moisan/repos
# 1      https://api.github.com/users/WindSoilder/repos
# 2           https://api.github.com/users/Moisan/repos
# 3      https://api.github.com/users/WindSoilder/repos
# 4       https://api.github.com/users/topper-123/repos
# 5       https://api.github.com/users/lukemanley/repos
# 6         https://api.github.com/users/Th3nn3ss/repos
# 7       https://api.github.com/users/ramvikrams/repos
# 8         https://api.github.com/users/Th3nn3ss/repos
# 9            https://api.github.com/users/csala/repos
# 10    https://api.github.com/users/jbrockmendel/repos
# 11      https://api.github.com/users/rhshadrach/repos
# 12           https://api.github.com/users/phofl/repos
# 13           https://api.github.com/users/phofl/repos
# 14    https://api.github.com/users/jbrockmendel/repos
# 15      https://api.github.com/users/rhshadrach/repos
# 16    https://api.github.com/users/jbrockmendel/repos
# 17      https://api.github.com/users/topper-123/repos
# 18      https://api.github.com/users/topper-123/repos
# 19      https://api.github.com/users/topper-123/repos
# 20  https://api.github.com/users/thlautenschlaeger...
# 21        https://api.github.com/users/cdcadman/repos
# 22    https://api.github.com/users/jbrockmendel/repos
# 23        https://api.github.com/users/noritada/repos
# 24    https://api.github.com/users/arnaudlegout/repos
# 25  https://api.github.com/users/jorisvandenbossch...
# 26  https://api.github.com/users/jorisvandenbossch...
# 27         https://api.github.com/users/anbjork/repos
# 28  https://api.github.com/users/jorisvandenbossch...
# 29             https://api.github.com/users/akx/repos
# 30       https://api.github.com/users/david6l34/repos
# 31        https://api.github.com/users/it176131/repos
#
#                                            events_url  \
# 0   https://api.github.com/users/Moisan/events{/pr...
# 1   https://api.github.com/users/WindSoilder/event...
# 2   https://api.github.com/users/Moisan/events{/pr...
# 3   https://api.github.com/users/WindSoilder/event...
# 4   https://api.github.com/users/topper-123/events...
# 5   https://api.github.com/users/lukemanley/events...
# 6   https://api.github.com/users/Th3nn3ss/events{/...
# 7   https://api.github.com/users/ramvikrams/events...
# 8   https://api.github.com/users/Th3nn3ss/events{/...
# 9   https://api.github.com/users/csala/events{/pri...
# 10  https://api.github.com/users/jbrockmendel/even...
# 11  https://api.github.com/users/rhshadrach/events...
# 12  https://api.github.com/users/phofl/events{/pri...
# 13  https://api.github.com/users/phofl/events{/pri...
# 14  https://api.github.com/users/jbrockmendel/even...
# 15  https://api.github.com/users/rhshadrach/events...
# 16  https://api.github.com/users/jbrockmendel/even...
# 17  https://api.github.com/users/topper-123/events...
# 18  https://api.github.com/users/topper-123/events...
# 19  https://api.github.com/users/topper-123/events...
# 20  https://api.github.com/users/thlautenschlaeger...
# 21  https://api.github.com/users/cdcadman/events{/...
# 22  https://api.github.com/users/jbrockmendel/even...
# 23  https://api.github.com/users/noritada/events{/...
# 24  https://api.github.com/users/arnaudlegout/even...
# 25  https://api.github.com/users/jorisvandenbossch...
# 26  https://api.github.com/users/jorisvandenbossch...
# 27  https://api.github.com/users/anbjork/events{/p...
# 28  https://api.github.com/users/jorisvandenbossch...
# 29  https://api.github.com/users/akx/events{/privacy}
# 30  https://api.github.com/users/david6l34/events{...
# 31  https://api.github.com/users/it176131/events{/...
#
#                                   received_events_url  type  site_admin
# 0   https://api.github.com/users/Moisan/received_e...  User       False
# 1   https://api.github.com/users/WindSoilder/recei...  User       False
# 2   https://api.github.com/users/Moisan/received_e...  User       False
# 3   https://api.github.com/users/WindSoilder/recei...  User       False
# 4   https://api.github.com/users/topper-123/receiv...  User       False
# 5   https://api.github.com/users/lukemanley/receiv...  User       False
# 6   https://api.github.com/users/Th3nn3ss/received...  User       False
# 7   https://api.github.com/users/ramvikrams/receiv...  User       False
# 8   https://api.github.com/users/Th3nn3ss/received...  User       False
# 9   https://api.github.com/users/csala/received_ev...  User       False
# 10  https://api.github.com/users/jbrockmendel/rece...  User       False
# 11  https://api.github.com/users/rhshadrach/receiv...  User       False
# 12  https://api.github.com/users/phofl/received_ev...  User       False
# 13  https://api.github.com/users/phofl/received_ev...  User       False
# 14  https://api.github.com/users/jbrockmendel/rece...  User       False
# 15  https://api.github.com/users/rhshadrach/receiv...  User       False
# 16  https://api.github.com/users/jbrockmendel/rece...  User       False
# 17  https://api.github.com/users/topper-123/receiv...  User       False
# 18  https://api.github.com/users/topper-123/receiv...  User       False
# 19  https://api.github.com/users/topper-123/receiv...  User       False
# 20  https://api.github.com/users/thlautenschlaeger...  User       False
# 21  https://api.github.com/users/cdcadman/received...  User       False
# 22  https://api.github.com/users/jbrockmendel/rece...  User       False
# 23  https://api.github.com/users/noritada/received...  User       False
# 24  https://api.github.com/users/arnaudlegout/rece...  User       False
# 25  https://api.github.com/users/jorisvandenbossch...  User       False
# 26  https://api.github.com/users/jorisvandenbossch...  User       False
# 27  https://api.github.com/users/anbjork/received_...  User       False
# 28  https://api.github.com/users/jorisvandenbossch...  User       False
# 29   https://api.github.com/users/akx/received_events  User       False
# 30  https://api.github.com/users/david6l34/receive...  User       False
# 31  https://api.github.com/users/it176131/received...  User       False

# %%
for i in range(len(js)):
    print(js[i]['title'])
# Out:
# Fix pylint use-a-generator warning
# BUG: pd.read_sql with sql can failed when running query with % character
# DEPR: Remove int64 uint64 float64 index part 1
# BUG/PERF: MultiIndex.value_counts returning flat index
# ENH/CoW: use lazy copy in set_index method
# for gh-49508 changing Doc for DataFrame.astype
# ENH/CoW: use lazy copy on replace method
# ENH: Expose date parsing arguments in `read_html` function
# DEPR: enforce a bunch
# DEPR: Enforce deprecation of numeric_only=None in DataFrame aggregations
# CLN: Deduplicate code in duplicated
# ENH: Support mask in Int64Factorizer
# REF: remove unreachable maybe_cast_to_datetime cases
# API: Consolidate groupby as_index and group_keys
# REF: separate out seen.nat_ cases in maybe_convert_objects
# BUG: NumericIndex.astype(complex) should return Index[complex]
# BUG: NumericIndex should not support float16 dtype
# BUG: NumericIndex should not support float16 dtype
# BUG: inconsistent DataFrame.agg behavoir when passing as kwargs numeric_only=True
# Refactor sqlalchemy code in pandas.io.sql to help prepare for sqlalchemy 2.0.
# DEPR: enforce Series.__setitem__ behavior with Float64Index and non-present int key
# DOC: correctly format bullets in parameter descriptions for `fillna` methods
# DOC: `DataFrame.agg` and `Series.agg` documentation is unclear on which function we can use
# API / CoW: constructing Series from Series creates lazy copy (with default copy=False)
# API: should creating a Series from a Series return a shallow copy? (share data, not attributes)
# BUG: IndexError: .iloc requires numeric indexers, got [0 1 2 3]
# BUG?: groupby with as_index=False doesn't add grouper as column when passing a Series as group key
# STYLE/PERF: replace string concatenations with f-strings in core
# BUG: Full outer of single index dataframe on multi-index dataframe behavior not as expected
# ENH: Parameter `keep_equal` in `.compare(...)` method should not rely on the `keep_shape` parameter
