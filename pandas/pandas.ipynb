# %%
import pandas as pd

# %%
import requests

# %%
res=requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
js=res.json()

# %%
js[0]['title']
# Out:
# 'CLN: Remove MultiIndex._get_grouper_for_level'

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49597',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49597/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49597/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49597/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49597',
#   'id': 1441281911,
#   'node_id': 'PR_kwDOAA0YD85CezlY',
#   'number': 49597,
#   'title': 'CLN: Remove MultiIndex._get_grouper_for_level',
#   'user': {'login': 'codamuse',
#    'id': 116989963,
#    'node_id': 'U_kgDOBvkgCw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/116989963?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codamuse',
#    'html_url': 'https://github.com/codamuse',
#    'followers_url': 'https://api.github.com/users/codamuse/followers',
#    'following_url': 'https://api.github.com/users/codamuse/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/codamuse/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/codamuse/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/codamuse/subscriptions',
#    'organizations_url': 'https://api.github.com/users/codamuse/orgs',
#    'repos_url': 'https://api.github.com/users/codamuse/repos',
#    'events_url': 'https://api.github.com/users/codamuse/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/codamuse/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-09T03:08:02Z',
#   'updated_at': '2022-11-09T03:11:43Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49597',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49597',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49597.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49597.patch',
#    'merged_at': None},
#   'body': '- [x] closes #49452 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49597/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49597/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49596',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49596/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49596/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49596/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49596',
#   'id': 1441233836,
#   'node_id': 'PR_kwDOAA0YD85CepWM',
#   'number': 49596,
#   'title': 'PERF: df.groupby(categorical)',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 78527356,
#     'node_id': 'MDU6TGFiZWw3ODUyNzM1Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Categorical',
#     'name': 'Categorical',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Categorical Data Type'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-09T02:14:34Z',
#   'updated_at': '2022-11-09T02:32:01Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49596',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49596',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49596.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49596.patch',
#    'merged_at': None},
#   'body': '- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.0.0.rst` file if fixing a bug or adding a new feature.\r\n\r\nPerf improvement in `Categorical.reorder_categories` with user facing performance improvements likely to be `DataFrame.groupby(categorical)`. \r\n\r\n```\r\nimport pandas as pd\r\nimport pandas._testing as tm\r\n\r\nvals = pd.Series(tm.rands_array(10, 10**6), dtype="string")\r\ndf = pd.DataFrame({"cat": vals.astype("category")})\r\n\r\n%timeit df.groupby("cat").size()\r\n\r\n1.21 s ± 4.71 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)     <- main\r\n15.1 ms ± 274 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)  <- PR\r\n```\r\n\r\n\r\nexisting ASVs:\r\n```\r\n       before           after         ratio\r\n     [d69e63d7]       [382245ad]\r\n     <main>           <cat-reorder-categories>\r\n-      3.91±0.1ms       3.08±0.1ms     0.79  groupby.Categories.time_groupby_nosort\r\n-     3.54±0.04ms      2.31±0.02ms     0.65  groupby.Categories.time_groupby_extra_cat_nosort\r\n-     3.85±0.05ms       2.39±0.1ms     0.62  groupby.Categories.time_groupby_ordered_nosort\r\n-     2.05±0.01ms          514±6μs     0.25  groupby.Categories.time_groupby_extra_cat_sort\r\n-      2.21±0.1ms          536±4μs     0.24  groupby.Categories.time_groupby_sort\r\n-      2.23±0.1ms         523±30μs     0.23  groupby.Categories.time_groupby_ordered_sort\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49596/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49596/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49595',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49595/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49595/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49595/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49595',
#   'id': 1441210027,
#   'node_id': 'PR_kwDOAA0YD85CekLC',
#   'number': 49595,
#   'title': 'STYLE: fix pylint useless-else-on-loop warnings',
#   'user': {'login': 'Moisan',
#    'id': 31669,
#    'node_id': 'MDQ6VXNlcjMxNjY5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31669?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Moisan',
#    'html_url': 'https://github.com/Moisan',
#    'followers_url': 'https://api.github.com/users/Moisan/followers',
#    'following_url': 'https://api.github.com/users/Moisan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Moisan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Moisan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Moisan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Moisan/orgs',
#    'repos_url': 'https://api.github.com/users/Moisan/repos',
#    'events_url': 'https://api.github.com/users/Moisan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Moisan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-09T01:51:00Z',
#   'updated_at': '2022-11-09T01:51:00Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49595',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49595',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49595.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49595.patch',
#    'merged_at': None},
#   'body': 'Related to https://github.com/pandas-dev/pandas/issues/48855\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49595/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49595/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49594',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49594/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49594/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49594/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49594',
#   'id': 1441133384,
#   'node_id': 'PR_kwDOAA0YD85CeTZK',
#   'number': 49594,
#   'title': 'API: Index(object_dtype_bool_ndarray) retain object dtype',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-09T00:34:20Z',
#   'updated_at': '2022-11-09T00:37:51Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49594',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49594',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49594.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49594.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49594/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49594/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49593',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49593/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49593/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49593/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/49593',
#   'id': 1441130503,
#   'node_id': 'I_kwDOAA0YD85V5egH',
#   'number': 49593,
#   'title': 'API: DataFrame(list_with_ea)',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1465286368,
#     'node_id': 'MDU6TGFiZWwxNDY1Mjg2MzY4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Constructors',
#     'name': 'Constructors',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': 'Series/DataFrame/Index/pd.array Constructors'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-09T00:31:32Z',
#   'updated_at': '2022-11-09T00:47:24Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': '`DataFrame(nested_list)` generally treats each list entry as a row.  The exception (until #49592) is if the first element is a Categorical in which we treated elements as columns.  We have zero tests passing a `list[EA]` except when the first entry is a Categorical, which suggests to me that the behavior here has not gotten much attention.\r\n\r\nFor non-EA and some EAs (Period, dt64tz, interval) inference basically works right.  But for Categorical, pyarrow, and presumably 3rd-party EAs it doesn\'t:\r\n\r\n```\r\ndf = pd.DataFrame(np.arange(9).reshape(3, 3)).astype("int64[pyarrow]")\r\narrs = [df[i]._values for i in range(3)]\r\npd.DataFrame(arrs).dtypes  # <- back to numpy dtypes\r\n```\r\n\r\nWe could reasonably use concat-like logic for dtype inference.  (or for EAs that support 2D could just concat directly).\r\n\r\nAnother approach that might work is to do something like `DataFrame({i: rows[i] for i in range(len(rows))}).T`.  That works in the pyarrow example above.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49593/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49593/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49592',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49592/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49592/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49592/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49592',
#   'id': 1441117570,
#   'node_id': 'PR_kwDOAA0YD85CeP3Q',
#   'number': 49592,
#   'title': 'DEPR: Enforce DataFrame(list_with_categorical) deprecation',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-09T00:18:30Z',
#   'updated_at': '2022-11-09T00:18:30Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49592',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49592',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49592.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49592.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49592/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49592/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49591',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49591/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49591/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49591/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49591',
#   'id': 1441019159,
#   'node_id': 'PR_kwDOAA0YD85Cd6FX',
#   'number': 49591,
#   'title': 'REF: tighter typing in constructor functions',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-08T22:44:22Z',
#   'updated_at': '2022-11-08T22:44:22Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49591',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49591',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49591.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49591.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49591/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49591/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49590',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49590/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49590/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49590/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49590',
#   'id': 1440994193,
#   'node_id': 'PR_kwDOAA0YD85Cd0i4',
#   'number': 49590,
#   'title': 'CLN: assorted',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-08T22:20:26Z',
#   'updated_at': '2022-11-08T22:20:26Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49590',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49590',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49590.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49590.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49590/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49590/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49587',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49587/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49587/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49587/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49587',
#   'id': 1440784284,
#   'node_id': 'PR_kwDOAA0YD85CdH1m',
#   'number': 49587,
#   'title': 'TYP:Replace union of subclasses with base class.',
#   'user': {'login': 'cdcadman',
#    'id': 51368516,
#    'node_id': 'MDQ6VXNlcjUxMzY4NTE2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51368516?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cdcadman',
#    'html_url': 'https://github.com/cdcadman',
#    'followers_url': 'https://api.github.com/users/cdcadman/followers',
#    'following_url': 'https://api.github.com/users/cdcadman/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cdcadman/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cdcadman/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cdcadman/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cdcadman/orgs',
#    'repos_url': 'https://api.github.com/users/cdcadman/repos',
#    'events_url': 'https://api.github.com/users/cdcadman/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cdcadman/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-08T19:30:16Z',
#   'updated_at': '2022-11-09T00:47:36Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49587',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49587',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49587.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49587.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [X] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nI am splitting this out of #49531 . In order to refactor the code in that PR, I had to change the return type of `pandasSQL_builder`, and that forced me to make additional changes in order to make mypy pass in CI:\r\n* Line 581 (`pandas_sql.meta.reflect(bind=pandas_sql.connectable, only=[sql])`) was failing mypy, but it can be deleted since the table is reflected in `SQLDatabase.get_table`, when the `sqlalchemy.Table` object is created.\r\n* I declared all required functions in `PandasSQL` and made them raise `AbstractMethodError` (consistent with `BaseEngine.insert_records`.  I then made all the arguments agree between `PandasSQL` and subclasses.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49587/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49587/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49586',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49586/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49586/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49586/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49586',
#   'id': 1440701946,
#   'node_id': 'PR_kwDOAA0YD85Cc11Y',
#   'number': 49586,
#   'title': 'STYLE enable pylint: chained-comparison',
#   'user': {'login': 'natmokval',
#    'id': 91160475,
#    'node_id': 'MDQ6VXNlcjkxMTYwNDc1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91160475?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/natmokval',
#    'html_url': 'https://github.com/natmokval',
#    'followers_url': 'https://api.github.com/users/natmokval/followers',
#    'following_url': 'https://api.github.com/users/natmokval/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/natmokval/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/natmokval/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/natmokval/subscriptions',
#    'organizations_url': 'https://api.github.com/users/natmokval/orgs',
#    'repos_url': 'https://api.github.com/users/natmokval/repos',
#    'events_url': 'https://api.github.com/users/natmokval/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/natmokval/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 106935113,
#     'node_id': 'MDU6TGFiZWwxMDY5MzUxMTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Code%20Style',
#     'name': 'Code Style',
#     'color': 'eb6420',
#     'default': False,
#     'description': 'Code style, linting, code_checks'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/42',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42/labels',
#    'id': 1945020,
#    'node_id': 'MDk6TWlsZXN0b25lMTk0NTAyMA==',
#    'number': 42,
#    'title': '2.0',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 38,
#    'closed_issues': 510,
#    'state': 'open',
#    'created_at': '2016-08-16T13:21:24Z',
#    'updated_at': '2022-11-08T23:42:54Z',
#    'due_on': '2022-12-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-11-08T18:28:16Z',
#   'updated_at': '2022-11-08T19:27:23Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49586',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49586',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49586.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49586.patch',
#    'merged_at': None},
#   'body': 'Issue #48855. This PR enables pylint type "R" warning: ` chained-comparison`\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49586/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49586/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49585',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49585/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49585/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49585/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/49585',
#   'id': 1440699897,
#   'node_id': 'I_kwDOAA0YD85V31X5',
#   'number': 49585,
#   'title': 'BUG: Series read_json tries to convert all column values to dates even when using keep_default_dates=True, if one column has an na value',
#   'user': {'login': 'efagerberg',
#    'id': 7632073,
#    'node_id': 'MDQ6VXNlcjc2MzIwNzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7632073?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efagerberg',
#    'html_url': 'https://github.com/efagerberg',
#    'followers_url': 'https://api.github.com/users/efagerberg/followers',
#    'following_url': 'https://api.github.com/users/efagerberg/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efagerberg/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efagerberg/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efagerberg/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efagerberg/orgs',
#    'repos_url': 'https://api.github.com/users/efagerberg/repos',
#    'events_url': 'https://api.github.com/users/efagerberg/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efagerberg/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-11-08T18:26:36Z',
#   'updated_at': '2022-11-08T22:59:02Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nx = pd.Series({\'a\': None, \'b\': \'012345\', \'c\': 1})\r\nprint(x)\r\nprint(\r\n    pd.read_json(\r\n        pd.Series(x).to_json(),\r\n        typ="series",\r\n        orient="records",\r\n        keep_default_dates=True,\r\n    )\r\n)\r\n\r\n\r\na      None\r\nb    012345\r\nc         1\r\ndtype: object\r\na                   NaT\r\nb   1970-01-01 03:25:45\r\nc   1970-01-01 00:00:01\r\ndtype: datetime64[ns]\r\n\r\n\r\n# Without na column\r\n\r\nx = pd.Series({\'b\': \'012345\', \'c\': 1})\r\nprint(x)\r\nprint(\r\n    pd.read_json(\r\n        pd.Series(x).to_json(),\r\n        typ="series",\r\n        orient="records",\r\n        keep_default_dates=True,\r\n    )\r\n)\r\n\r\nb    012345\r\nc         1\r\ndtype: object\r\nb    12345\r\nc        1\r\ndtype: int64\n```\n\n\n### Issue Description\n\nWhen a series has a column that could be parsed as a date, and when there is another column with an na value, `read_json` will convert all columns to datetimes.\n\n### Expected Behavior\n\nIdeally none of the columns would be parsed as dates, unless I set `keep_default_dates=False` or I do not supply it.\n\n### Installed Versions\n\n<details>\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 91111fd99898d9dcaa6bf6bedb662db4108da6e6\r\npython           : 3.9.6.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.15.0-52-generic\r\nVersion          : #58-Ubuntu SMP Thu Oct 13 08:03:55 UTC 2022\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.5.1\r\nnumpy            : 1.22.2\r\npytz             : 2022.6\r\ndateutil         : 2.8.2\r\nsetuptools       : 65.5.0\r\npip              : 22.1.2\r\nCython           : None\r\npytest           : 6.2.5\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : 2.8.6\r\njinja2           : 3.1.2\r\nIPython          : 7.34.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : 2022.10.0\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : 0.56.3\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.9.3\r\nsnappy           : None\r\nsqlalchemy       : 1.4.42\r\ntables           : None\r\ntabulate         : 0.9.0\r\nxarray           : None\r\nxlrd             : 2.0.1\r\nxlwt             : 1.3.0\r\nzstandard        : None\r\ntzdata           : None\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49585/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49585/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49584',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49584/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49584/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49584/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49584',
#   'id': 1440561543,
#   'node_id': 'PR_kwDOAA0YD85CcXVe',
#   'number': 49584,
#   'title': 'add/timedeltas-seconds-documentation',
#   'user': {'login': 'joaopmjm',
#    'id': 26440584,
#    'node_id': 'MDQ6VXNlcjI2NDQwNTg0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26440584?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joaopmjm',
#    'html_url': 'https://github.com/joaopmjm',
#    'followers_url': 'https://api.github.com/users/joaopmjm/followers',
#    'following_url': 'https://api.github.com/users/joaopmjm/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/joaopmjm/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/joaopmjm/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/joaopmjm/subscriptions',
#    'organizations_url': 'https://api.github.com/users/joaopmjm/orgs',
#    'repos_url': 'https://api.github.com/users/joaopmjm/repos',
#    'events_url': 'https://api.github.com/users/joaopmjm/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/joaopmjm/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-08T16:55:27Z',
#   'updated_at': '2022-11-09T00:19:07Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49584',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49584',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49584.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49584.patch',
#    'merged_at': None},
#   'body': '- [x] closes #49568',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49584/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49584/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49583',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49583/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49583/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49583/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49583',
#   'id': 1440543982,
#   'node_id': 'PR_kwDOAA0YD85CcTi4',
#   'number': 49583,
#   'title': 'API: stop special-casing SparseArray._quantile',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
# ...
#   'number': 49565,
#   'title': 'BUG: when `floor`ing, `ambiguous` parameter unnecessarily used (and raising Error) ',
#   'user': {'login': 'rwijtvliet',
#    'id': 4106013,
#    'node_id': 'MDQ6VXNlcjQxMDYwMTM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4106013?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rwijtvliet',
#    'html_url': 'https://github.com/rwijtvliet',
#    'followers_url': 'https://api.github.com/users/rwijtvliet/followers',
#    'following_url': 'https://api.github.com/users/rwijtvliet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rwijtvliet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rwijtvliet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rwijtvliet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rwijtvliet/orgs',
#    'repos_url': 'https://api.github.com/users/rwijtvliet/repos',
#    'events_url': 'https://api.github.com/users/rwijtvliet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rwijtvliet/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-07T16:47:35Z',
#   'updated_at': '2022-11-07T16:52:14Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\nts = pd.Timestamp("2020-10-25 00:00", tz=\'Europe/Berlin\')\r\n# This works:\r\nts.floor(\'H\') # Timestamp(\'2020-10-25 00:00:00+0200\', tz=\'Europe/Berlin\')\r\n# But this gives an error:\r\nts.floor(\'H\', ambiguous=\'infer\') # ValueError: Cannot infer offset with only one time.\n```\n\n\n### Issue Description\n\nThe value of the `ambiguous` parameter is used by the method, even if there is no ambiguity.\n\n### Expected Behavior\n\nBoth calls to the `.floor` method should give the same outcome.\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 91111fd99898d9dcaa6bf6bedb662db4108da6e6\r\npython           : 3.9.13.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19045\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 165 Stepping 2, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : de_DE.cp1252\r\n\r\npandas           : 1.5.1\r\nnumpy            : 1.23.4\r\npytz             : 2022.6\r\ndateutil         : 2.8.2\r\nsetuptools       : 63.4.1\r\npip              : 22.2.2\r\nCython           : None\r\npytest           : 7.1.3\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : 8.5.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : 3.6.2\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49565/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49565/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49561',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49561/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49561/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49561/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/49561',
#   'id': 1437669869,
#   'node_id': 'I_kwDOAA0YD85VsRnt',
#   'number': 49561,
#   'title': 'BUG: pd.read_sql with sql can failed when running query with % character',
#   'user': {'login': 'WindSoilder',
#    'id': 22256154,
#    'node_id': 'MDQ6VXNlcjIyMjU2MTU0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22256154?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WindSoilder',
#    'html_url': 'https://github.com/WindSoilder',
#    'followers_url': 'https://api.github.com/users/WindSoilder/followers',
#    'following_url': 'https://api.github.com/users/WindSoilder/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/WindSoilder/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/WindSoilder/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/WindSoilder/subscriptions',
#    'organizations_url': 'https://api.github.com/users/WindSoilder/orgs',
#    'repos_url': 'https://api.github.com/users/WindSoilder/repos',
#    'events_url': 'https://api.github.com/users/WindSoilder/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/WindSoilder/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-07T02:20:31Z',
#   'updated_at': '2022-11-07T02:24:22Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [x] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\nimport sqlalchemy\r\n# the database server need to be mysql, and we need to connect to server\r\nengine = sqlalchemy.create_engine("mysql://a:b@localhost")\r\npd.read_sql("select a from x WHERE b LIKE %2%", engine)\r\n```\r\n\r\n\r\n\r\n### Issue Description\r\n\r\n1. firstly we need to have a mysql server\r\n2. then execute the code in reproducible example\r\n3. an exception occured: `ValueError: unsupported format character \'%\' (0x25) at index 31`\r\n\r\n\r\n### Expected Behavior\r\n\r\npandas shouldn\'t raise ValueError.\r\n\r\nIn addition: I\'ve confimed it works fine on version 1.1.*(like 1.1.3), the issue is happend when `pandas >= 1.2`\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 91111fd99898d9dcaa6bf6bedb662db4108da6e6\r\npython           : 3.8.13.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 4.14.105-19-0016\r\nVersion          : #1 SMP Wed Sep 23 19:31:42 CST 2020\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : en_US.UTF-8\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.5.1\r\nnumpy            : 1.22.4\r\npytz             : 2022.6\r\ndateutil         : 2.8.2\r\nsetuptools       : 61.2.0\r\npip              : 21.2.4\r\nCython           : 0.29.28\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : 1.0.2\r\npsycopg2         : None\r\njinja2           : 2.11.2\r\nIPython          : 8.6.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           :\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.7.3\r\nsnappy           : None\r\nsqlalchemy       : 1.4.42\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49561/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49561/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49560',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49560/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49560/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49560/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/49560',
#   'id': 1437564458,
#   'node_id': 'PR_kwDOAA0YD85CSQ0n',
#   'number': 49560,
#   'title': 'DEPR: Remove int64 uint64 float64 index part 1',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-11-06T22:32:20Z',
#   'updated_at': '2022-11-08T12:42:14Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/49560',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/49560',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/49560.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/49560.patch',
#    'merged_at': None},
#   'body': "*Not ready for review, I still need to see if the errors in the CI are different than locally*\r\n\r\nI had some problems with #49494, so I'm closing that and trying again with a more focused PR.\r\n\r\nThis PR makes progress towards removing Int64Index, UInt64Index & FloatIndex from the code base, see #42717.\r\n\r\nIn this PR I make instantiation of `Index` with numpy numeric dtypes return a `NumericIndex` with the given dtype rather than converting to the old 64 bit only numeric index types, making all numeric dtypes available for indexes.\r\n\r\nThis is just the first part of the changes planned. In follow-ups PRs I will:\r\n* remove Int64Index, Uint64Index & Float64Index from the top namespace\r\n* remove Int64Index, Uint64Index & Float64Index from the code base entirely (also internally)\r\n* Move the functionality of `NumericIndex`into the base `Index` and remove `NumericIndex`\r\n* Update docs to reflect the above changes\r\n\r\n## related PRs\r\nA part of the problems I had in #49494 was a few corner case bugs. They're pulled out into seperate PRs (#49536 & #49540). They're present in this PR at present, but will be removed after those seperate PRs have been merged.\r\n\r\n## Notable changes from this PR:\r\nAs mentioned in #49494, one notable change from the PR is that because we now have all the numeric dtypes available for indexes, indexes created from DateTimeIndex (day, year etc.) will now be in int32, where previously they were forced to int64 (because that was the only index integer dtype available).\r\n\r\nUsing int32 is the more correct way, because the underlying `DateTimeArray` returns 32bit arrays. An example of this:\r\n\r\n```ipython\r\n>>> import pandas as pd\r\n>>> \r\n>>> x = pd.date_range(start='1/1/2018', end='1/08/2018')\r\n>>> x.array.day\r\narray([1, 2, 3, 4, 5, 6, 7, 8], dtype=int32)  # 32bit, current and will not be changed in this series of PRs\r\n>>> x.day\r\nInt64Index([1, 2, 3, 4, 5, 6, 7, 8], dtype='int64')  # before this PR\r\nNumericIndex([1, 2, 3, 4, 5, 6, 7, 8], dtype='int32')  # after this PR\r\nIndex([1, 2, 3, 4, 5, 6, 7, 8], dtype='int32')  # after follow-up PRs\r\n```\r\n\r\nThe above will be included in the doc changes, when I do the docs\r\n\r\nProgress towards #42717. See also #41272",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49560/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/49560/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
lis=[]

# %%
lis.append(js[0]['user'])

# %%
lis.append(js[1]['user'])

# %%
lis
# Out:
# [{'login': 'codamuse',
#   'id': 116989963,
#   'node_id': 'U_kgDOBvkgCw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/116989963?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/codamuse',
#   'html_url': 'https://github.com/codamuse',
#   'followers_url': 'https://api.github.com/users/codamuse/followers',
#   'following_url': 'https://api.github.com/users/codamuse/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/codamuse/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/codamuse/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/codamuse/subscriptions',
#   'organizations_url': 'https://api.github.com/users/codamuse/orgs',
#   'repos_url': 'https://api.github.com/users/codamuse/repos',
#   'events_url': 'https://api.github.com/users/codamuse/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/codamuse/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'lukemanley',
#   'id': 8519523,
#   'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/lukemanley',
#   'html_url': 'https://github.com/lukemanley',
#   'followers_url': 'https://api.github.com/users/lukemanley/followers',
#   'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#   'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#   'repos_url': 'https://api.github.com/users/lukemanley/repos',
#   'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#   'type': 'User',
#   'site_admin': False}]

# %%
for i in range(len(js)):
    lis.append(js[i]['user'])

# %%
pd.DataFrame(lis).to_csv("user.csv",index=False)

# %%
pd.read_csv('user.csv')
# Out:
#            login         id               node_id  \
# 0       codamuse  116989963          U_kgDOBvkgCw
# 1     lukemanley    8519523  MDQ6VXNlcjg1MTk1MjM=
# 2       codamuse  116989963          U_kgDOBvkgCw
# 3     lukemanley    8519523  MDQ6VXNlcjg1MTk1MjM=
# 4         Moisan      31669      MDQ6VXNlcjMxNjY5
# 5   jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 6   jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 7   jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 8   jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 9   jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 10      cdcadman   51368516  MDQ6VXNlcjUxMzY4NTE2
# 11     natmokval   91160475  MDQ6VXNlcjkxMTYwNDc1
# 12    efagerberg    7632073  MDQ6VXNlcjc2MzIwNzM=
# 13      joaopmjm   26440584  MDQ6VXNlcjI2NDQwNTg0
# 14  jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 15       mar-ses   17413212  MDQ6VXNlcjE3NDEzMjEy
# 16           2-5    3753822  MDQ6VXNlcjM3NTM4MjI=
# 17       joooeey   28426758  MDQ6VXNlcjI4NDI2NzU4
# 18        krasch    3533957  MDQ6VXNlcjM1MzM5NTc=
# 19     deepyaman   14007150  MDQ6VXNlcjE0MDA3MTUw
# 20    MikaelUmaN    1746060  MDQ6VXNlcjE3NDYwNjA=
# 21    topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 22    topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 23    topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 24    topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 25       Samreay    6748505  MDQ6VXNlcjY3NDg1MDU=
# 26     mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 27        Zaijab   40334752  MDQ6VXNlcjQwMzM0NzUy
# 28    rwijtvliet    4106013  MDQ6VXNlcjQxMDYwMTM=
# 29    rwijtvliet    4106013  MDQ6VXNlcjQxMDYwMTM=
# 30   WindSoilder   22256154  MDQ6VXNlcjIyMjU2MTU0
# 31    topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
#
#                                            avatar_url  gravatar_id  \
# 0   https://avatars.githubusercontent.com/u/116989...          NaN
# 1   https://avatars.githubusercontent.com/u/851952...          NaN
# 2   https://avatars.githubusercontent.com/u/116989...          NaN
# 3   https://avatars.githubusercontent.com/u/851952...          NaN
# 4   https://avatars.githubusercontent.com/u/31669?v=4          NaN
# 5   https://avatars.githubusercontent.com/u/807896...          NaN
# 6   https://avatars.githubusercontent.com/u/807896...          NaN
# 7   https://avatars.githubusercontent.com/u/807896...          NaN
# 8   https://avatars.githubusercontent.com/u/807896...          NaN
# 9   https://avatars.githubusercontent.com/u/807896...          NaN
# 10  https://avatars.githubusercontent.com/u/513685...          NaN
# 11  https://avatars.githubusercontent.com/u/911604...          NaN
# 12  https://avatars.githubusercontent.com/u/763207...          NaN
# 13  https://avatars.githubusercontent.com/u/264405...          NaN
# 14  https://avatars.githubusercontent.com/u/807896...          NaN
# 15  https://avatars.githubusercontent.com/u/174132...          NaN
# 16  https://avatars.githubusercontent.com/u/375382...          NaN
# 17  https://avatars.githubusercontent.com/u/284267...          NaN
# 18  https://avatars.githubusercontent.com/u/353395...          NaN
# 19  https://avatars.githubusercontent.com/u/140071...          NaN
# 20  https://avatars.githubusercontent.com/u/174606...          NaN
# 21  https://avatars.githubusercontent.com/u/263644...          NaN
# 22  https://avatars.githubusercontent.com/u/263644...          NaN
# 23  https://avatars.githubusercontent.com/u/263644...          NaN
# 24  https://avatars.githubusercontent.com/u/263644...          NaN
# 25  https://avatars.githubusercontent.com/u/674850...          NaN
# 26  https://avatars.githubusercontent.com/u/106470...          NaN
# 27  https://avatars.githubusercontent.com/u/403347...          NaN
# 28  https://avatars.githubusercontent.com/u/410601...          NaN
# 29  https://avatars.githubusercontent.com/u/410601...          NaN
# 30  https://avatars.githubusercontent.com/u/222561...          NaN
# 31  https://avatars.githubusercontent.com/u/263644...          NaN
#
#                                           url  \
# 0       https://api.github.com/users/codamuse
# 1     https://api.github.com/users/lukemanley
# 2       https://api.github.com/users/codamuse
# 3     https://api.github.com/users/lukemanley
# 4         https://api.github.com/users/Moisan
# 5   https://api.github.com/users/jbrockmendel
# 6   https://api.github.com/users/jbrockmendel
# 7   https://api.github.com/users/jbrockmendel
# 8   https://api.github.com/users/jbrockmendel
# 9   https://api.github.com/users/jbrockmendel
# 10      https://api.github.com/users/cdcadman
# 11     https://api.github.com/users/natmokval
# 12    https://api.github.com/users/efagerberg
# 13      https://api.github.com/users/joaopmjm
# 14  https://api.github.com/users/jbrockmendel
# 15       https://api.github.com/users/mar-ses
# 16           https://api.github.com/users/2-5
# 17       https://api.github.com/users/joooeey
# 18        https://api.github.com/users/krasch
# 19     https://api.github.com/users/deepyaman
# 20    https://api.github.com/users/MikaelUmaN
# 21    https://api.github.com/users/topper-123
# 22    https://api.github.com/users/topper-123
# 23    https://api.github.com/users/topper-123
# 24    https://api.github.com/users/topper-123
# 25       https://api.github.com/users/Samreay
# 26     https://api.github.com/users/mroeschke
# 27        https://api.github.com/users/Zaijab
# 28    https://api.github.com/users/rwijtvliet
# 29    https://api.github.com/users/rwijtvliet
# 30   https://api.github.com/users/WindSoilder
# 31    https://api.github.com/users/topper-123
#
#                            html_url  \
# 0       https://github.com/codamuse
# 1     https://github.com/lukemanley
# 2       https://github.com/codamuse
# 3     https://github.com/lukemanley
# 4         https://github.com/Moisan
# 5   https://github.com/jbrockmendel
# 6   https://github.com/jbrockmendel
# 7   https://github.com/jbrockmendel
# 8   https://github.com/jbrockmendel
# 9   https://github.com/jbrockmendel
# 10      https://github.com/cdcadman
# 11     https://github.com/natmokval
# 12    https://github.com/efagerberg
# 13      https://github.com/joaopmjm
# 14  https://github.com/jbrockmendel
# 15       https://github.com/mar-ses
# 16           https://github.com/2-5
# 17       https://github.com/joooeey
# 18        https://github.com/krasch
# 19     https://github.com/deepyaman
# 20    https://github.com/MikaelUmaN
# 21    https://github.com/topper-123
# 22    https://github.com/topper-123
# 23    https://github.com/topper-123
# 24    https://github.com/topper-123
# 25       https://github.com/Samreay
# 26     https://github.com/mroeschke
# 27        https://github.com/Zaijab
# 28    https://github.com/rwijtvliet
# 29    https://github.com/rwijtvliet
# 30   https://github.com/WindSoilder
# 31    https://github.com/topper-123
#
#                                         followers_url  \
# 0     https://api.github.com/users/codamuse/followers
# 1   https://api.github.com/users/lukemanley/followers
# 2     https://api.github.com/users/codamuse/followers
# 3   https://api.github.com/users/lukemanley/followers
# 4       https://api.github.com/users/Moisan/followers
# 5   https://api.github.com/users/jbrockmendel/foll...
# 6   https://api.github.com/users/jbrockmendel/foll...
# 7   https://api.github.com/users/jbrockmendel/foll...
# 8   https://api.github.com/users/jbrockmendel/foll...
# 9   https://api.github.com/users/jbrockmendel/foll...
# 10    https://api.github.com/users/cdcadman/followers
# 11   https://api.github.com/users/natmokval/followers
# 12  https://api.github.com/users/efagerberg/followers
# 13    https://api.github.com/users/joaopmjm/followers
# 14  https://api.github.com/users/jbrockmendel/foll...
# 15     https://api.github.com/users/mar-ses/followers
# 16         https://api.github.com/users/2-5/followers
# 17     https://api.github.com/users/joooeey/followers
# 18      https://api.github.com/users/krasch/followers
# 19   https://api.github.com/users/deepyaman/followers
# 20  https://api.github.com/users/MikaelUmaN/followers
# 21  https://api.github.com/users/topper-123/followers
# 22  https://api.github.com/users/topper-123/followers
# 23  https://api.github.com/users/topper-123/followers
# 24  https://api.github.com/users/topper-123/followers
# 25     https://api.github.com/users/Samreay/followers
# 26   https://api.github.com/users/mroeschke/followers
# 27      https://api.github.com/users/Zaijab/followers
# 28  https://api.github.com/users/rwijtvliet/followers
# 29  https://api.github.com/users/rwijtvliet/followers
# 30  https://api.github.com/users/WindSoilder/follo...
# 31  https://api.github.com/users/topper-123/followers
#
#                                         following_url  \
# 0   https://api.github.com/users/codamuse/followin...
# 1   https://api.github.com/users/lukemanley/follow...
# 2   https://api.github.com/users/codamuse/followin...
# 3   https://api.github.com/users/lukemanley/follow...
# 4   https://api.github.com/users/Moisan/following{...
# 5   https://api.github.com/users/jbrockmendel/foll...
# 6   https://api.github.com/users/jbrockmendel/foll...
# 7   https://api.github.com/users/jbrockmendel/foll...
# 8   https://api.github.com/users/jbrockmendel/foll...
# 9   https://api.github.com/users/jbrockmendel/foll...
# 10  https://api.github.com/users/cdcadman/followin...
# 11  https://api.github.com/users/natmokval/followi...
# 12  https://api.github.com/users/efagerberg/follow...
# 13  https://api.github.com/users/joaopmjm/followin...
# 14  https://api.github.com/users/jbrockmendel/foll...
# 15  https://api.github.com/users/mar-ses/following...
# 16  https://api.github.com/users/2-5/following{/ot...
# 17  https://api.github.com/users/joooeey/following...
# 18  https://api.github.com/users/krasch/following{...
# 19  https://api.github.com/users/deepyaman/followi...
# 20  https://api.github.com/users/MikaelUmaN/follow...
# 21  https://api.github.com/users/topper-123/follow...
# 22  https://api.github.com/users/topper-123/follow...
# 23  https://api.github.com/users/topper-123/follow...
# 24  https://api.github.com/users/topper-123/follow...
# 25  https://api.github.com/users/Samreay/following...
# 26  https://api.github.com/users/mroeschke/followi...
# 27  https://api.github.com/users/Zaijab/following{...
# 28  https://api.github.com/users/rwijtvliet/follow...
# 29  https://api.github.com/users/rwijtvliet/follow...
# 30  https://api.github.com/users/WindSoilder/follo...
# 31  https://api.github.com/users/topper-123/follow...
#
#                                             gists_url  \
# 0   https://api.github.com/users/codamuse/gists{/g...
# 1   https://api.github.com/users/lukemanley/gists{...
# 2   https://api.github.com/users/codamuse/gists{/g...
# 3   https://api.github.com/users/lukemanley/gists{...
# 4   https://api.github.com/users/Moisan/gists{/gis...
# 5   https://api.github.com/users/jbrockmendel/gist...
# 6   https://api.github.com/users/jbrockmendel/gist...
# 7   https://api.github.com/users/jbrockmendel/gist...
# 8   https://api.github.com/users/jbrockmendel/gist...
# 9   https://api.github.com/users/jbrockmendel/gist...
# 10  https://api.github.com/users/cdcadman/gists{/g...
# 11  https://api.github.com/users/natmokval/gists{/...
# 12  https://api.github.com/users/efagerberg/gists{...
# 13  https://api.github.com/users/joaopmjm/gists{/g...
# 14  https://api.github.com/users/jbrockmendel/gist...
# 15  https://api.github.com/users/mar-ses/gists{/gi...
# 16   https://api.github.com/users/2-5/gists{/gist_id}
# 17  https://api.github.com/users/joooeey/gists{/gi...
# 18  https://api.github.com/users/krasch/gists{/gis...
# 19  https://api.github.com/users/deepyaman/gists{/...
# 20  https://api.github.com/users/MikaelUmaN/gists{...
# 21  https://api.github.com/users/topper-123/gists{...
# 22  https://api.github.com/users/topper-123/gists{...
# 23  https://api.github.com/users/topper-123/gists{...
# 24  https://api.github.com/users/topper-123/gists{...
# 25  https://api.github.com/users/Samreay/gists{/gi...
# 26  https://api.github.com/users/mroeschke/gists{/...
# 27  https://api.github.com/users/Zaijab/gists{/gis...
# 28  https://api.github.com/users/rwijtvliet/gists{...
# 29  https://api.github.com/users/rwijtvliet/gists{...
# 30  https://api.github.com/users/WindSoilder/gists...
# 31  https://api.github.com/users/topper-123/gists{...
#
#                                           starred_url  \
# 0   https://api.github.com/users/codamuse/starred{...
# 1   https://api.github.com/users/lukemanley/starre...
# 2   https://api.github.com/users/codamuse/starred{...
# 3   https://api.github.com/users/lukemanley/starre...
# 4   https://api.github.com/users/Moisan/starred{/o...
# 5   https://api.github.com/users/jbrockmendel/star...
# 6   https://api.github.com/users/jbrockmendel/star...
# 7   https://api.github.com/users/jbrockmendel/star...
# 8   https://api.github.com/users/jbrockmendel/star...
# 9   https://api.github.com/users/jbrockmendel/star...
# 10  https://api.github.com/users/cdcadman/starred{...
# 11  https://api.github.com/users/natmokval/starred...
# 12  https://api.github.com/users/efagerberg/starre...
# 13  https://api.github.com/users/joaopmjm/starred{...
# 14  https://api.github.com/users/jbrockmendel/star...
# 15  https://api.github.com/users/mar-ses/starred{/...
# 16  https://api.github.com/users/2-5/starred{/owne...
# 17  https://api.github.com/users/joooeey/starred{/...
# 18  https://api.github.com/users/krasch/starred{/o...
# 19  https://api.github.com/users/deepyaman/starred...
# 20  https://api.github.com/users/MikaelUmaN/starre...
# 21  https://api.github.com/users/topper-123/starre...
# 22  https://api.github.com/users/topper-123/starre...
# 23  https://api.github.com/users/topper-123/starre...
# 24  https://api.github.com/users/topper-123/starre...
# 25  https://api.github.com/users/Samreay/starred{/...
# 26  https://api.github.com/users/mroeschke/starred...
# 27  https://api.github.com/users/Zaijab/starred{/o...
# 28  https://api.github.com/users/rwijtvliet/starre...
# 29  https://api.github.com/users/rwijtvliet/starre...
# 30  https://api.github.com/users/WindSoilder/starr...
# 31  https://api.github.com/users/topper-123/starre...
#
#                                     subscriptions_url  \
# 0   https://api.github.com/users/codamuse/subscrip...
# 1   https://api.github.com/users/lukemanley/subscr...
# 2   https://api.github.com/users/codamuse/subscrip...
# 3   https://api.github.com/users/lukemanley/subscr...
# 4   https://api.github.com/users/Moisan/subscriptions
# 5   https://api.github.com/users/jbrockmendel/subs...
# 6   https://api.github.com/users/jbrockmendel/subs...
# 7   https://api.github.com/users/jbrockmendel/subs...
# 8   https://api.github.com/users/jbrockmendel/subs...
# 9   https://api.github.com/users/jbrockmendel/subs...
# 10  https://api.github.com/users/cdcadman/subscrip...
# 11  https://api.github.com/users/natmokval/subscri...
# 12  https://api.github.com/users/efagerberg/subscr...
# 13  https://api.github.com/users/joaopmjm/subscrip...
# 14  https://api.github.com/users/jbrockmendel/subs...
# 15  https://api.github.com/users/mar-ses/subscript...
# 16     https://api.github.com/users/2-5/subscriptions
# 17  https://api.github.com/users/joooeey/subscript...
# 18  https://api.github.com/users/krasch/subscriptions
# 19  https://api.github.com/users/deepyaman/subscri...
# 20  https://api.github.com/users/MikaelUmaN/subscr...
# 21  https://api.github.com/users/topper-123/subscr...
# 22  https://api.github.com/users/topper-123/subscr...
# 23  https://api.github.com/users/topper-123/subscr...
# 24  https://api.github.com/users/topper-123/subscr...
# 25  https://api.github.com/users/Samreay/subscript...
# 26  https://api.github.com/users/mroeschke/subscri...
# 27  https://api.github.com/users/Zaijab/subscriptions
# 28  https://api.github.com/users/rwijtvliet/subscr...
# 29  https://api.github.com/users/rwijtvliet/subscr...
# 30  https://api.github.com/users/WindSoilder/subsc...
# 31  https://api.github.com/users/topper-123/subscr...
#
#                                  organizations_url  \
# 0       https://api.github.com/users/codamuse/orgs
# 1     https://api.github.com/users/lukemanley/orgs
# 2       https://api.github.com/users/codamuse/orgs
# 3     https://api.github.com/users/lukemanley/orgs
# 4         https://api.github.com/users/Moisan/orgs
# 5   https://api.github.com/users/jbrockmendel/orgs
# 6   https://api.github.com/users/jbrockmendel/orgs
# 7   https://api.github.com/users/jbrockmendel/orgs
# 8   https://api.github.com/users/jbrockmendel/orgs
# 9   https://api.github.com/users/jbrockmendel/orgs
# 10      https://api.github.com/users/cdcadman/orgs
# 11     https://api.github.com/users/natmokval/orgs
# 12    https://api.github.com/users/efagerberg/orgs
# 13      https://api.github.com/users/joaopmjm/orgs
# 14  https://api.github.com/users/jbrockmendel/orgs
# 15       https://api.github.com/users/mar-ses/orgs
# 16           https://api.github.com/users/2-5/orgs
# 17       https://api.github.com/users/joooeey/orgs
# 18        https://api.github.com/users/krasch/orgs
# 19     https://api.github.com/users/deepyaman/orgs
# 20    https://api.github.com/users/MikaelUmaN/orgs
# 21    https://api.github.com/users/topper-123/orgs
# 22    https://api.github.com/users/topper-123/orgs
# 23    https://api.github.com/users/topper-123/orgs
# 24    https://api.github.com/users/topper-123/orgs
# 25       https://api.github.com/users/Samreay/orgs
# 26     https://api.github.com/users/mroeschke/orgs
# 27        https://api.github.com/users/Zaijab/orgs
# 28    https://api.github.com/users/rwijtvliet/orgs
# 29    https://api.github.com/users/rwijtvliet/orgs
# 30   https://api.github.com/users/WindSoilder/orgs
# 31    https://api.github.com/users/topper-123/orgs
#
#                                           repos_url  \
# 0       https://api.github.com/users/codamuse/repos
# 1     https://api.github.com/users/lukemanley/repos
# 2       https://api.github.com/users/codamuse/repos
# 3     https://api.github.com/users/lukemanley/repos
# 4         https://api.github.com/users/Moisan/repos
# 5   https://api.github.com/users/jbrockmendel/repos
# 6   https://api.github.com/users/jbrockmendel/repos
# 7   https://api.github.com/users/jbrockmendel/repos
# 8   https://api.github.com/users/jbrockmendel/repos
# 9   https://api.github.com/users/jbrockmendel/repos
# 10      https://api.github.com/users/cdcadman/repos
# 11     https://api.github.com/users/natmokval/repos
# 12    https://api.github.com/users/efagerberg/repos
# 13      https://api.github.com/users/joaopmjm/repos
# 14  https://api.github.com/users/jbrockmendel/repos
# 15       https://api.github.com/users/mar-ses/repos
# 16           https://api.github.com/users/2-5/repos
# 17       https://api.github.com/users/joooeey/repos
# 18        https://api.github.com/users/krasch/repos
# 19     https://api.github.com/users/deepyaman/repos
# 20    https://api.github.com/users/MikaelUmaN/repos
# 21    https://api.github.com/users/topper-123/repos
# 22    https://api.github.com/users/topper-123/repos
# 23    https://api.github.com/users/topper-123/repos
# 24    https://api.github.com/users/topper-123/repos
# 25       https://api.github.com/users/Samreay/repos
# 26     https://api.github.com/users/mroeschke/repos
# 27        https://api.github.com/users/Zaijab/repos
# 28    https://api.github.com/users/rwijtvliet/repos
# 29    https://api.github.com/users/rwijtvliet/repos
# 30   https://api.github.com/users/WindSoilder/repos
# 31    https://api.github.com/users/topper-123/repos
#
#                                            events_url  \
# 0   https://api.github.com/users/codamuse/events{/...
# 1   https://api.github.com/users/lukemanley/events...
# 2   https://api.github.com/users/codamuse/events{/...
# 3   https://api.github.com/users/lukemanley/events...
# 4   https://api.github.com/users/Moisan/events{/pr...
# 5   https://api.github.com/users/jbrockmendel/even...
# 6   https://api.github.com/users/jbrockmendel/even...
# 7   https://api.github.com/users/jbrockmendel/even...
# 8   https://api.github.com/users/jbrockmendel/even...
# 9   https://api.github.com/users/jbrockmendel/even...
# 10  https://api.github.com/users/cdcadman/events{/...
# 11  https://api.github.com/users/natmokval/events{...
# 12  https://api.github.com/users/efagerberg/events...
# 13  https://api.github.com/users/joaopmjm/events{/...
# 14  https://api.github.com/users/jbrockmendel/even...
# 15  https://api.github.com/users/mar-ses/events{/p...
# 16  https://api.github.com/users/2-5/events{/privacy}
# 17  https://api.github.com/users/joooeey/events{/p...
# 18  https://api.github.com/users/krasch/events{/pr...
# 19  https://api.github.com/users/deepyaman/events{...
# 20  https://api.github.com/users/MikaelUmaN/events...
# 21  https://api.github.com/users/topper-123/events...
# 22  https://api.github.com/users/topper-123/events...
# 23  https://api.github.com/users/topper-123/events...
# 24  https://api.github.com/users/topper-123/events...
# 25  https://api.github.com/users/Samreay/events{/p...
# 26  https://api.github.com/users/mroeschke/events{...
# 27  https://api.github.com/users/Zaijab/events{/pr...
# 28  https://api.github.com/users/rwijtvliet/events...
# 29  https://api.github.com/users/rwijtvliet/events...
# 30  https://api.github.com/users/WindSoilder/event...
# 31  https://api.github.com/users/topper-123/events...
#
#                                   received_events_url  type  site_admin
# 0   https://api.github.com/users/codamuse/received...  User       False
# 1   https://api.github.com/users/lukemanley/receiv...  User       False
# 2   https://api.github.com/users/codamuse/received...  User       False
# 3   https://api.github.com/users/lukemanley/receiv...  User       False
# 4   https://api.github.com/users/Moisan/received_e...  User       False
# 5   https://api.github.com/users/jbrockmendel/rece...  User       False
# 6   https://api.github.com/users/jbrockmendel/rece...  User       False
# 7   https://api.github.com/users/jbrockmendel/rece...  User       False
# 8   https://api.github.com/users/jbrockmendel/rece...  User       False
# 9   https://api.github.com/users/jbrockmendel/rece...  User       False
# 10  https://api.github.com/users/cdcadman/received...  User       False
# 11  https://api.github.com/users/natmokval/receive...  User       False
# 12  https://api.github.com/users/efagerberg/receiv...  User       False
# 13  https://api.github.com/users/joaopmjm/received...  User       False
# 14  https://api.github.com/users/jbrockmendel/rece...  User       False
# 15  https://api.github.com/users/mar-ses/received_...  User       False
# 16   https://api.github.com/users/2-5/received_events  User       False
# 17  https://api.github.com/users/joooeey/received_...  User       False
# 18  https://api.github.com/users/krasch/received_e...  User       False
# 19  https://api.github.com/users/deepyaman/receive...  User       False
# 20  https://api.github.com/users/MikaelUmaN/receiv...  User       False
# 21  https://api.github.com/users/topper-123/receiv...  User       False
# 22  https://api.github.com/users/topper-123/receiv...  User       False
# 23  https://api.github.com/users/topper-123/receiv...  User       False
# 24  https://api.github.com/users/topper-123/receiv...  User       False
# 25  https://api.github.com/users/Samreay/received_...  User       False
# 26  https://api.github.com/users/mroeschke/receive...  User       False
# 27  https://api.github.com/users/Zaijab/received_e...  User       False
# 28  https://api.github.com/users/rwijtvliet/receiv...  User       False
# 29  https://api.github.com/users/rwijtvliet/receiv...  User       False
# 30  https://api.github.com/users/WindSoilder/recei...  User       False
# 31  https://api.github.com/users/topper-123/receiv...  User       False

# %%
pd.DataFrame(lis).to_csv("user1.csv")

# %%
data=pd.read_csv('user1.csv')

# %%
for i in range(len(js)):
    print(js[i]['title'])
# Out:
# Fix pylint use-a-generator warning
# BUG: pd.read_sql with sql can failed when running query with % character
# DEPR: Remove int64 uint64 float64 index part 1
# BUG/PERF: MultiIndex.value_counts returning flat index
# ENH/CoW: use lazy copy in set_index method
# for gh-49508 changing Doc for DataFrame.astype
# ENH/CoW: use lazy copy on replace method
# ENH: Expose date parsing arguments in `read_html` function
# DEPR: enforce a bunch
# DEPR: Enforce deprecation of numeric_only=None in DataFrame aggregations
# CLN: Deduplicate code in duplicated
# ENH: Support mask in Int64Factorizer
# REF: remove unreachable maybe_cast_to_datetime cases
# API: Consolidate groupby as_index and group_keys
# REF: separate out seen.nat_ cases in maybe_convert_objects
# BUG: NumericIndex.astype(complex) should return Index[complex]
# BUG: NumericIndex should not support float16 dtype
# BUG: NumericIndex should not support float16 dtype
# BUG: inconsistent DataFrame.agg behavoir when passing as kwargs numeric_only=True
# Refactor sqlalchemy code in pandas.io.sql to help prepare for sqlalchemy 2.0.
# DEPR: enforce Series.__setitem__ behavior with Float64Index and non-present int key
# DOC: correctly format bullets in parameter descriptions for `fillna` methods
# DOC: `DataFrame.agg` and `Series.agg` documentation is unclear on which function we can use
# API / CoW: constructing Series from Series creates lazy copy (with default copy=False)
# API: should creating a Series from a Series return a shallow copy? (share data, not attributes)
# BUG: IndexError: .iloc requires numeric indexers, got [0 1 2 3]
# BUG?: groupby with as_index=False doesn't add grouper as column when passing a Series as group key
# STYLE/PERF: replace string concatenations with f-strings in core
# BUG: Full outer of single index dataframe on multi-index dataframe behavior not as expected
# ENH: Parameter `keep_equal` in `.compare(...)` method should not rely on the `keep_shape` parameter

# %%
data[['id']].min()
# Out:
# id    31669
# dtype: int64

# %%
data[data[['id']]==data[['id']].min()]['id']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4     31669.0
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# 30        NaN
# 31        NaN
# Name: id, dtype: float64

# %%
import numpy as np

# %%
data.iloc[np.where(data['id']>31669)]
# Out:
#     Unnamed: 0         login         id               node_id  \
# 0            0      codamuse  116989963          U_kgDOBvkgCw
# 1            1    lukemanley    8519523  MDQ6VXNlcjg1MTk1MjM=
# 2            2      codamuse  116989963          U_kgDOBvkgCw
# 3            3    lukemanley    8519523  MDQ6VXNlcjg1MTk1MjM=
# 5            5  jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 6            6  jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 7            7  jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 8            8  jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 9            9  jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 10          10      cdcadman   51368516  MDQ6VXNlcjUxMzY4NTE2
# 11          11     natmokval   91160475  MDQ6VXNlcjkxMTYwNDc1
# 12          12    efagerberg    7632073  MDQ6VXNlcjc2MzIwNzM=
# 13          13      joaopmjm   26440584  MDQ6VXNlcjI2NDQwNTg0
# 14          14  jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 15          15       mar-ses   17413212  MDQ6VXNlcjE3NDEzMjEy
# 16          16           2-5    3753822  MDQ6VXNlcjM3NTM4MjI=
# 17          17       joooeey   28426758  MDQ6VXNlcjI4NDI2NzU4
# 18          18        krasch    3533957  MDQ6VXNlcjM1MzM5NTc=
# 19          19     deepyaman   14007150  MDQ6VXNlcjE0MDA3MTUw
# 20          20    MikaelUmaN    1746060  MDQ6VXNlcjE3NDYwNjA=
# 21          21    topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 22          22    topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 23          23    topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 24          24    topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
# 25          25       Samreay    6748505  MDQ6VXNlcjY3NDg1MDU=
# 26          26     mroeschke   10647082  MDQ6VXNlcjEwNjQ3MDgy
# 27          27        Zaijab   40334752  MDQ6VXNlcjQwMzM0NzUy
# 28          28    rwijtvliet    4106013  MDQ6VXNlcjQxMDYwMTM=
# 29          29    rwijtvliet    4106013  MDQ6VXNlcjQxMDYwMTM=
# 30          30   WindSoilder   22256154  MDQ6VXNlcjIyMjU2MTU0
# 31          31    topper-123   26364415  MDQ6VXNlcjI2MzY0NDE1
#
#                                            avatar_url  gravatar_id  \
# 0   https://avatars.githubusercontent.com/u/116989...          NaN
# 1   https://avatars.githubusercontent.com/u/851952...          NaN
# 2   https://avatars.githubusercontent.com/u/116989...          NaN
# 3   https://avatars.githubusercontent.com/u/851952...          NaN
# 5   https://avatars.githubusercontent.com/u/807896...          NaN
# 6   https://avatars.githubusercontent.com/u/807896...          NaN
# 7   https://avatars.githubusercontent.com/u/807896...          NaN
# 8   https://avatars.githubusercontent.com/u/807896...          NaN
# 9   https://avatars.githubusercontent.com/u/807896...          NaN
# 10  https://avatars.githubusercontent.com/u/513685...          NaN
# 11  https://avatars.githubusercontent.com/u/911604...          NaN
# 12  https://avatars.githubusercontent.com/u/763207...          NaN
# 13  https://avatars.githubusercontent.com/u/264405...          NaN
# 14  https://avatars.githubusercontent.com/u/807896...          NaN
# 15  https://avatars.githubusercontent.com/u/174132...          NaN
# 16  https://avatars.githubusercontent.com/u/375382...          NaN
# 17  https://avatars.githubusercontent.com/u/284267...          NaN
# 18  https://avatars.githubusercontent.com/u/353395...          NaN
# 19  https://avatars.githubusercontent.com/u/140071...          NaN
# 20  https://avatars.githubusercontent.com/u/174606...          NaN
# 21  https://avatars.githubusercontent.com/u/263644...          NaN
# 22  https://avatars.githubusercontent.com/u/263644...          NaN
# 23  https://avatars.githubusercontent.com/u/263644...          NaN
# 24  https://avatars.githubusercontent.com/u/263644...          NaN
# 25  https://avatars.githubusercontent.com/u/674850...          NaN
# 26  https://avatars.githubusercontent.com/u/106470...          NaN
# 27  https://avatars.githubusercontent.com/u/403347...          NaN
# 28  https://avatars.githubusercontent.com/u/410601...          NaN
# 29  https://avatars.githubusercontent.com/u/410601...          NaN
# 30  https://avatars.githubusercontent.com/u/222561...          NaN
# 31  https://avatars.githubusercontent.com/u/263644...          NaN
#
#                                           url  \
# 0       https://api.github.com/users/codamuse
# 1     https://api.github.com/users/lukemanley
# 2       https://api.github.com/users/codamuse
# 3     https://api.github.com/users/lukemanley
# 5   https://api.github.com/users/jbrockmendel
# 6   https://api.github.com/users/jbrockmendel
# 7   https://api.github.com/users/jbrockmendel
# 8   https://api.github.com/users/jbrockmendel
# 9   https://api.github.com/users/jbrockmendel
# 10      https://api.github.com/users/cdcadman
# 11     https://api.github.com/users/natmokval
# 12    https://api.github.com/users/efagerberg
# 13      https://api.github.com/users/joaopmjm
# 14  https://api.github.com/users/jbrockmendel
# 15       https://api.github.com/users/mar-ses
# 16           https://api.github.com/users/2-5
# 17       https://api.github.com/users/joooeey
# 18        https://api.github.com/users/krasch
# 19     https://api.github.com/users/deepyaman
# 20    https://api.github.com/users/MikaelUmaN
# 21    https://api.github.com/users/topper-123
# 22    https://api.github.com/users/topper-123
# 23    https://api.github.com/users/topper-123
# 24    https://api.github.com/users/topper-123
# 25       https://api.github.com/users/Samreay
# 26     https://api.github.com/users/mroeschke
# 27        https://api.github.com/users/Zaijab
# 28    https://api.github.com/users/rwijtvliet
# 29    https://api.github.com/users/rwijtvliet
# 30   https://api.github.com/users/WindSoilder
# 31    https://api.github.com/users/topper-123
#
#                            html_url  \
# 0       https://github.com/codamuse
# 1     https://github.com/lukemanley
# 2       https://github.com/codamuse
# 3     https://github.com/lukemanley
# 5   https://github.com/jbrockmendel
# 6   https://github.com/jbrockmendel
# 7   https://github.com/jbrockmendel
# 8   https://github.com/jbrockmendel
# 9   https://github.com/jbrockmendel
# 10      https://github.com/cdcadman
# 11     https://github.com/natmokval
# 12    https://github.com/efagerberg
# 13      https://github.com/joaopmjm
# 14  https://github.com/jbrockmendel
# 15       https://github.com/mar-ses
# 16           https://github.com/2-5
# 17       https://github.com/joooeey
# 18        https://github.com/krasch
# 19     https://github.com/deepyaman
# 20    https://github.com/MikaelUmaN
# 21    https://github.com/topper-123
# 22    https://github.com/topper-123
# 23    https://github.com/topper-123
# 24    https://github.com/topper-123
# 25       https://github.com/Samreay
# 26     https://github.com/mroeschke
# 27        https://github.com/Zaijab
# 28    https://github.com/rwijtvliet
# 29    https://github.com/rwijtvliet
# 30   https://github.com/WindSoilder
# 31    https://github.com/topper-123
#
#                                         followers_url  \
# 0     https://api.github.com/users/codamuse/followers
# 1   https://api.github.com/users/lukemanley/followers
# 2     https://api.github.com/users/codamuse/followers
# 3   https://api.github.com/users/lukemanley/followers
# 5   https://api.github.com/users/jbrockmendel/foll...
# 6   https://api.github.com/users/jbrockmendel/foll...
# 7   https://api.github.com/users/jbrockmendel/foll...
# 8   https://api.github.com/users/jbrockmendel/foll...
# 9   https://api.github.com/users/jbrockmendel/foll...
# 10    https://api.github.com/users/cdcadman/followers
# 11   https://api.github.com/users/natmokval/followers
# 12  https://api.github.com/users/efagerberg/followers
# 13    https://api.github.com/users/joaopmjm/followers
# 14  https://api.github.com/users/jbrockmendel/foll...
# 15     https://api.github.com/users/mar-ses/followers
# 16         https://api.github.com/users/2-5/followers
# 17     https://api.github.com/users/joooeey/followers
# 18      https://api.github.com/users/krasch/followers
# 19   https://api.github.com/users/deepyaman/followers
# 20  https://api.github.com/users/MikaelUmaN/followers
# 21  https://api.github.com/users/topper-123/followers
# 22  https://api.github.com/users/topper-123/followers
# 23  https://api.github.com/users/topper-123/followers
# 24  https://api.github.com/users/topper-123/followers
# 25     https://api.github.com/users/Samreay/followers
# 26   https://api.github.com/users/mroeschke/followers
# 27      https://api.github.com/users/Zaijab/followers
# 28  https://api.github.com/users/rwijtvliet/followers
# 29  https://api.github.com/users/rwijtvliet/followers
# 30  https://api.github.com/users/WindSoilder/follo...
# 31  https://api.github.com/users/topper-123/followers
#
#                                         following_url  \
# 0   https://api.github.com/users/codamuse/followin...
# 1   https://api.github.com/users/lukemanley/follow...
# 2   https://api.github.com/users/codamuse/followin...
# 3   https://api.github.com/users/lukemanley/follow...
# 5   https://api.github.com/users/jbrockmendel/foll...
# 6   https://api.github.com/users/jbrockmendel/foll...
# 7   https://api.github.com/users/jbrockmendel/foll...
# 8   https://api.github.com/users/jbrockmendel/foll...
# 9   https://api.github.com/users/jbrockmendel/foll...
# 10  https://api.github.com/users/cdcadman/followin...
# 11  https://api.github.com/users/natmokval/followi...
# 12  https://api.github.com/users/efagerberg/follow...
# 13  https://api.github.com/users/joaopmjm/followin...
# 14  https://api.github.com/users/jbrockmendel/foll...
# 15  https://api.github.com/users/mar-ses/following...
# 16  https://api.github.com/users/2-5/following{/ot...
# 17  https://api.github.com/users/joooeey/following...
# 18  https://api.github.com/users/krasch/following{...
# 19  https://api.github.com/users/deepyaman/followi...
# 20  https://api.github.com/users/MikaelUmaN/follow...
# 21  https://api.github.com/users/topper-123/follow...
# 22  https://api.github.com/users/topper-123/follow...
# 23  https://api.github.com/users/topper-123/follow...
# 24  https://api.github.com/users/topper-123/follow...
# 25  https://api.github.com/users/Samreay/following...
# 26  https://api.github.com/users/mroeschke/followi...
# 27  https://api.github.com/users/Zaijab/following{...
# 28  https://api.github.com/users/rwijtvliet/follow...
# 29  https://api.github.com/users/rwijtvliet/follow...
# 30  https://api.github.com/users/WindSoilder/follo...
# 31  https://api.github.com/users/topper-123/follow...
#
#                                             gists_url  \
# 0   https://api.github.com/users/codamuse/gists{/g...
# 1   https://api.github.com/users/lukemanley/gists{...
# 2   https://api.github.com/users/codamuse/gists{/g...
# 3   https://api.github.com/users/lukemanley/gists{...
# 5   https://api.github.com/users/jbrockmendel/gist...
# 6   https://api.github.com/users/jbrockmendel/gist...
# 7   https://api.github.com/users/jbrockmendel/gist...
# 8   https://api.github.com/users/jbrockmendel/gist...
# 9   https://api.github.com/users/jbrockmendel/gist...
# 10  https://api.github.com/users/cdcadman/gists{/g...
# 11  https://api.github.com/users/natmokval/gists{/...
# 12  https://api.github.com/users/efagerberg/gists{...
# 13  https://api.github.com/users/joaopmjm/gists{/g...
# 14  https://api.github.com/users/jbrockmendel/gist...
# 15  https://api.github.com/users/mar-ses/gists{/gi...
# 16   https://api.github.com/users/2-5/gists{/gist_id}
# 17  https://api.github.com/users/joooeey/gists{/gi...
# 18  https://api.github.com/users/krasch/gists{/gis...
# 19  https://api.github.com/users/deepyaman/gists{/...
# 20  https://api.github.com/users/MikaelUmaN/gists{...
# 21  https://api.github.com/users/topper-123/gists{...
# 22  https://api.github.com/users/topper-123/gists{...
# 23  https://api.github.com/users/topper-123/gists{...
# 24  https://api.github.com/users/topper-123/gists{...
# 25  https://api.github.com/users/Samreay/gists{/gi...
# 26  https://api.github.com/users/mroeschke/gists{/...
# 27  https://api.github.com/users/Zaijab/gists{/gis...
# 28  https://api.github.com/users/rwijtvliet/gists{...
# 29  https://api.github.com/users/rwijtvliet/gists{...
# 30  https://api.github.com/users/WindSoilder/gists...
# 31  https://api.github.com/users/topper-123/gists{...
#
#                                           starred_url  \
# 0   https://api.github.com/users/codamuse/starred{...
# 1   https://api.github.com/users/lukemanley/starre...
# 2   https://api.github.com/users/codamuse/starred{...
# 3   https://api.github.com/users/lukemanley/starre...
# 5   https://api.github.com/users/jbrockmendel/star...
# 6   https://api.github.com/users/jbrockmendel/star...
# 7   https://api.github.com/users/jbrockmendel/star...
# 8   https://api.github.com/users/jbrockmendel/star...
# 9   https://api.github.com/users/jbrockmendel/star...
# 10  https://api.github.com/users/cdcadman/starred{...
# 11  https://api.github.com/users/natmokval/starred...
# 12  https://api.github.com/users/efagerberg/starre...
# 13  https://api.github.com/users/joaopmjm/starred{...
# 14  https://api.github.com/users/jbrockmendel/star...
# 15  https://api.github.com/users/mar-ses/starred{/...
# 16  https://api.github.com/users/2-5/starred{/owne...
# 17  https://api.github.com/users/joooeey/starred{/...
# 18  https://api.github.com/users/krasch/starred{/o...
# 19  https://api.github.com/users/deepyaman/starred...
# 20  https://api.github.com/users/MikaelUmaN/starre...
# 21  https://api.github.com/users/topper-123/starre...
# 22  https://api.github.com/users/topper-123/starre...
# 23  https://api.github.com/users/topper-123/starre...
# 24  https://api.github.com/users/topper-123/starre...
# 25  https://api.github.com/users/Samreay/starred{/...
# 26  https://api.github.com/users/mroeschke/starred...
# 27  https://api.github.com/users/Zaijab/starred{/o...
# 28  https://api.github.com/users/rwijtvliet/starre...
# 29  https://api.github.com/users/rwijtvliet/starre...
# 30  https://api.github.com/users/WindSoilder/starr...
# 31  https://api.github.com/users/topper-123/starre...
#
#                                     subscriptions_url  \
# 0   https://api.github.com/users/codamuse/subscrip...
# 1   https://api.github.com/users/lukemanley/subscr...
# 2   https://api.github.com/users/codamuse/subscrip...
# 3   https://api.github.com/users/lukemanley/subscr...
# 5   https://api.github.com/users/jbrockmendel/subs...
# 6   https://api.github.com/users/jbrockmendel/subs...
# 7   https://api.github.com/users/jbrockmendel/subs...
# 8   https://api.github.com/users/jbrockmendel/subs...
# 9   https://api.github.com/users/jbrockmendel/subs...
# 10  https://api.github.com/users/cdcadman/subscrip...
# 11  https://api.github.com/users/natmokval/subscri...
# 12  https://api.github.com/users/efagerberg/subscr...
# 13  https://api.github.com/users/joaopmjm/subscrip...
# 14  https://api.github.com/users/jbrockmendel/subs...
# 15  https://api.github.com/users/mar-ses/subscript...
# 16     https://api.github.com/users/2-5/subscriptions
# 17  https://api.github.com/users/joooeey/subscript...
# 18  https://api.github.com/users/krasch/subscriptions
# 19  https://api.github.com/users/deepyaman/subscri...
# 20  https://api.github.com/users/MikaelUmaN/subscr...
# 21  https://api.github.com/users/topper-123/subscr...
# 22  https://api.github.com/users/topper-123/subscr...
# 23  https://api.github.com/users/topper-123/subscr...
# 24  https://api.github.com/users/topper-123/subscr...
# 25  https://api.github.com/users/Samreay/subscript...
# 26  https://api.github.com/users/mroeschke/subscri...
# 27  https://api.github.com/users/Zaijab/subscriptions
# 28  https://api.github.com/users/rwijtvliet/subscr...
# 29  https://api.github.com/users/rwijtvliet/subscr...
# 30  https://api.github.com/users/WindSoilder/subsc...
# 31  https://api.github.com/users/topper-123/subscr...
#
#                                  organizations_url  \
# 0       https://api.github.com/users/codamuse/orgs
# 1     https://api.github.com/users/lukemanley/orgs
# 2       https://api.github.com/users/codamuse/orgs
# 3     https://api.github.com/users/lukemanley/orgs
# 5   https://api.github.com/users/jbrockmendel/orgs
# 6   https://api.github.com/users/jbrockmendel/orgs
# 7   https://api.github.com/users/jbrockmendel/orgs
# 8   https://api.github.com/users/jbrockmendel/orgs
# 9   https://api.github.com/users/jbrockmendel/orgs
# 10      https://api.github.com/users/cdcadman/orgs
# 11     https://api.github.com/users/natmokval/orgs
# 12    https://api.github.com/users/efagerberg/orgs
# 13      https://api.github.com/users/joaopmjm/orgs
# 14  https://api.github.com/users/jbrockmendel/orgs
# 15       https://api.github.com/users/mar-ses/orgs
# 16           https://api.github.com/users/2-5/orgs
# 17       https://api.github.com/users/joooeey/orgs
# 18        https://api.github.com/users/krasch/orgs
# 19     https://api.github.com/users/deepyaman/orgs
# 20    https://api.github.com/users/MikaelUmaN/orgs
# 21    https://api.github.com/users/topper-123/orgs
# 22    https://api.github.com/users/topper-123/orgs
# 23    https://api.github.com/users/topper-123/orgs
# 24    https://api.github.com/users/topper-123/orgs
# 25       https://api.github.com/users/Samreay/orgs
# 26     https://api.github.com/users/mroeschke/orgs
# 27        https://api.github.com/users/Zaijab/orgs
# 28    https://api.github.com/users/rwijtvliet/orgs
# 29    https://api.github.com/users/rwijtvliet/orgs
# 30   https://api.github.com/users/WindSoilder/orgs
# 31    https://api.github.com/users/topper-123/orgs
#
#                                           repos_url  \
# 0       https://api.github.com/users/codamuse/repos
# 1     https://api.github.com/users/lukemanley/repos
# 2       https://api.github.com/users/codamuse/repos
# 3     https://api.github.com/users/lukemanley/repos
# 5   https://api.github.com/users/jbrockmendel/repos
# 6   https://api.github.com/users/jbrockmendel/repos
# 7   https://api.github.com/users/jbrockmendel/repos
# 8   https://api.github.com/users/jbrockmendel/repos
# 9   https://api.github.com/users/jbrockmendel/repos
# 10      https://api.github.com/users/cdcadman/repos
# 11     https://api.github.com/users/natmokval/repos
# 12    https://api.github.com/users/efagerberg/repos
# 13      https://api.github.com/users/joaopmjm/repos
# 14  https://api.github.com/users/jbrockmendel/repos
# 15       https://api.github.com/users/mar-ses/repos
# 16           https://api.github.com/users/2-5/repos
# 17       https://api.github.com/users/joooeey/repos
# 18        https://api.github.com/users/krasch/repos
# 19     https://api.github.com/users/deepyaman/repos
# 20    https://api.github.com/users/MikaelUmaN/repos
# 21    https://api.github.com/users/topper-123/repos
# 22    https://api.github.com/users/topper-123/repos
# 23    https://api.github.com/users/topper-123/repos
# 24    https://api.github.com/users/topper-123/repos
# 25       https://api.github.com/users/Samreay/repos
# 26     https://api.github.com/users/mroeschke/repos
# 27        https://api.github.com/users/Zaijab/repos
# 28    https://api.github.com/users/rwijtvliet/repos
# 29    https://api.github.com/users/rwijtvliet/repos
# 30   https://api.github.com/users/WindSoilder/repos
# 31    https://api.github.com/users/topper-123/repos
#
#                                            events_url  \
# 0   https://api.github.com/users/codamuse/events{/...
# 1   https://api.github.com/users/lukemanley/events...
# 2   https://api.github.com/users/codamuse/events{/...
# 3   https://api.github.com/users/lukemanley/events...
# 5   https://api.github.com/users/jbrockmendel/even...
# 6   https://api.github.com/users/jbrockmendel/even...
# 7   https://api.github.com/users/jbrockmendel/even...
# 8   https://api.github.com/users/jbrockmendel/even...
# 9   https://api.github.com/users/jbrockmendel/even...
# 10  https://api.github.com/users/cdcadman/events{/...
# 11  https://api.github.com/users/natmokval/events{...
# 12  https://api.github.com/users/efagerberg/events...
# 13  https://api.github.com/users/joaopmjm/events{/...
# 14  https://api.github.com/users/jbrockmendel/even...
# 15  https://api.github.com/users/mar-ses/events{/p...
# 16  https://api.github.com/users/2-5/events{/privacy}
# 17  https://api.github.com/users/joooeey/events{/p...
# 18  https://api.github.com/users/krasch/events{/pr...
# 19  https://api.github.com/users/deepyaman/events{...
# 20  https://api.github.com/users/MikaelUmaN/events...
# 21  https://api.github.com/users/topper-123/events...
# 22  https://api.github.com/users/topper-123/events...
# 23  https://api.github.com/users/topper-123/events...
# 24  https://api.github.com/users/topper-123/events...
# 25  https://api.github.com/users/Samreay/events{/p...
# 26  https://api.github.com/users/mroeschke/events{...
# 27  https://api.github.com/users/Zaijab/events{/pr...
# 28  https://api.github.com/users/rwijtvliet/events...
# 29  https://api.github.com/users/rwijtvliet/events...
# 30  https://api.github.com/users/WindSoilder/event...
# 31  https://api.github.com/users/topper-123/events...
#
#                                   received_events_url  type  site_admin
# 0   https://api.github.com/users/codamuse/received...  User       False
# 1   https://api.github.com/users/lukemanley/receiv...  User       False
# 2   https://api.github.com/users/codamuse/received...  User       False
# 3   https://api.github.com/users/lukemanley/receiv...  User       False
# 5   https://api.github.com/users/jbrockmendel/rece...  User       False
# 6   https://api.github.com/users/jbrockmendel/rece...  User       False
# 7   https://api.github.com/users/jbrockmendel/rece...  User       False
# 8   https://api.github.com/users/jbrockmendel/rece...  User       False
# 9   https://api.github.com/users/jbrockmendel/rece...  User       False
# 10  https://api.github.com/users/cdcadman/received...  User       False
# 11  https://api.github.com/users/natmokval/receive...  User       False
# 12  https://api.github.com/users/efagerberg/receiv...  User       False
# 13  https://api.github.com/users/joaopmjm/received...  User       False
# 14  https://api.github.com/users/jbrockmendel/rece...  User       False
# 15  https://api.github.com/users/mar-ses/received_...  User       False
# 16   https://api.github.com/users/2-5/received_events  User       False
# 17  https://api.github.com/users/joooeey/received_...  User       False
# 18  https://api.github.com/users/krasch/received_e...  User       False
# 19  https://api.github.com/users/deepyaman/receive...  User       False
# 20  https://api.github.com/users/MikaelUmaN/receiv...  User       False
# 21  https://api.github.com/users/topper-123/receiv...  User       False
# 22  https://api.github.com/users/topper-123/receiv...  User       False
# 23  https://api.github.com/users/topper-123/receiv...  User       False
# 24  https://api.github.com/users/topper-123/receiv...  User       False
# 25  https://api.github.com/users/Samreay/received_...  User       False
# 26  https://api.github.com/users/mroeschke/receive...  User       False
# 27  https://api.github.com/users/Zaijab/received_e...  User       False
# 28  https://api.github.com/users/rwijtvliet/receiv...  User       False
# 29  https://api.github.com/users/rwijtvliet/receiv...  User       False
# 30  https://api.github.com/users/WindSoilder/recei...  User       False
# 31  https://api.github.com/users/topper-123/receiv...  User       False

# %%
da

# %%
data.isnull().count()
# Out:
# Unnamed: 0             32
# login                  32
# id                     32
# node_id                32
# avatar_url             32
# gravatar_id            32
# url                    32
# html_url               32
# followers_url          32
# following_url          32
# gists_url              32
# starred_url            32
# subscriptions_url      32
# organizations_url      32
# repos_url              32
# events_url             32
# received_events_url    32
# type                   32
# site_admin             32
# dtype: int64

# %%
data.login[(data['id']==8519523) & (data['type']=='User')]
# Out:
# 1    lukemanley
# 3    lukemanley
# Name: login, dtype: object

# %%
d={'Name':["nitin kumar"],'age':[24]}

# %%
name_data=pd.DataFrame(d,index=["col1"])

# %%
arr=np.random.rand(3,4)

# %%
arr
# Out:
# array([[8.24423991e-01, 7.85789434e-01, 1.19280497e-01, 2.41753686e-01],
#        [8.12267476e-01, 4.53488105e-01, 2.80175073e-01, 8.44887161e-01],
#        [9.28607822e-02, 8.53661466e-01, 7.41489098e-01, 5.45818742e-04]])

# %%
pd.DataFrame(arr)
# Out:
#           0         1         2         3
# 0  0.824424  0.785789  0.119280  0.241754
# 1  0.812267  0.453488  0.280175  0.844887
# 2  0.092861  0.853661  0.741489  0.000546

# %%
name_data
# Out:
#              Name  age
# col1  nitin kumar   24

# %%
name_data.loc['col1']
# Out:
# Name    nitin kumar
# age              24
# Name: col1, dtype: object

# %%
matrix_data=pd.DataFrame(np.random.randint(3,6,(3,4)),index=['x','y','z'],columns=['a','b','c','d'])

# %%
matrix_data
# Out:
#    a  b  c  d
# x  4  4  3  4
# y  5  3  4  5
# z  3  5  3  4

# %%
matrix_data.iloc[1:,2:]
# Out:
#    c  d
# y  4  5
# z  3  4

# %%
matrix_data.loc['y':,'c':]
# Out:
#    c  d
# y  4  5
# z  3  4

# %%
matrix_data['a+b']=matrix_data['a']+matrix_data.b

# %%
matrix_data
# Out:
#    a  b  c  d  a+b
# x  4  4  3  4    8
# y  5  3  4  5    8
# z  3  5  3  4    8

# %%
data=pd.DataFrame(np.random.randn(3,4),index=['x','y','z'],columns=['a','b','c','d'])

# %%
data
# Out:
#           a         b         c         d
# x -0.880555  0.878501  0.423986 -1.316471
# y  1.886550 -0.074228  0.648857  0.778549
# z -1.293603 -0.244870 -0.093482 -0.594271

# %%
data.values[data.values<0]
# Out:
# array([-1.23655645, -0.33823628, -0.19340143])

# %%
data.values
# Out:
# array([[ 0.86562919,  0.16877379,  0.8095264 ,  0.37702606],
#        [ 2.45596785, -1.23655645,  0.18414014, -0.33823628],
#        [ 0.81311329, -0.19340143,  0.95702935,  1.19496819]])

# %%
data.iloc[np.where(data<0)]
# Out:
#           b         d         b
# y -1.236556 -0.338236 -1.236556
# y -1.236556 -0.338236 -1.236556
# z -0.193401  1.194968 -0.193401

# %%
data
# Out:
#           a         b         c         d
# x  0.865629  0.168774  0.809526  0.377026
# y  2.455968 -1.236556  0.184140 -0.338236
# z  0.813113 -0.193401  0.957029  1.194968

# %%
for i in data.columns:
    
    for j in data[i].index:
        if data.loc[j,i]<0:
            print(j,i,'-----',data.loc[j,i])
# Out:
# x a ----- -0.8805551568648783
# z a ----- -1.293603065517899
# y b ----- -0.07422835104224385
# z b ----- -0.24487026355415856
# z c ----- -0.09348157250066318
# x d ----- -1.3164705504679488
# z d ----- -0.5942714179121419

# %%
data.dropna()
# Out:
#           a         b         c         d
# x -0.880555  0.878501  0.423986 -1.316471
# y  1.886550 -0.074228  0.648857  0.778549
# z -1.293603 -0.244870 -0.093482 -0.594271

# %%
data["None"]=np.NaN

# %%
data
# Out:
#           a         b         c         d  None
# x -0.880555  0.878501  0.423986 -1.316471   NaN
# y  1.886550 -0.074228  0.648857  0.778549   NaN
# z -1.293603 -0.244870 -0.093482 -0.594271   NaN

# %%
data.dropna(axis=1)
# Out:
#           a         b         c         d
# x -0.880555  0.878501  0.423986 -1.316471
# y  1.886550 -0.074228  0.648857  0.778549
# z -1.293603 -0.244870 -0.093482 -0.594271

# %%
data.dropna(thresh=1)
# Out:
#           a         b         c         d  None
# x -0.880555  0.878501  0.423986 -1.316471   NaN
# y  1.886550 -0.074228  0.648857  0.778549   NaN
# z -1.293603 -0.244870 -0.093482 -0.594271   NaN

# %%
data.fillna(data.a.mean(),inplace=True)

# %%
data
# Out:
#           a         b         c         d      None
# x -0.880555  0.878501  0.423986 -1.316471 -0.095869
# y  1.886550 -0.074228  0.648857  0.778549 -0.095869
# z -1.293603 -0.244870 -0.093482 -0.594271 -0.095869

# %%
data.groupby('a').mean()
# Out:
#                   b         c         d      None
# a
# -1.293603 -0.244870 -0.093482 -0.594271 -0.095869
# -0.880555  0.878501  0.423986 -1.316471 -0.095869
#  1.886550 -0.074228  0.648857  0.778549 -0.095869

# %%
data.groupby('a').describe()
# Out:
#               b                                                        \
#           count      mean std       min       25%       50%       75%
# a
# -1.293603   1.0 -0.244870 NaN -0.244870 -0.244870 -0.244870 -0.244870
# -0.880555   1.0  0.878501 NaN  0.878501  0.878501  0.878501  0.878501
#  1.886550   1.0 -0.074228 NaN -0.074228 -0.074228 -0.074228 -0.074228
#
#                         c            ...         d            None            \
#                 max count      mean  ...       75%       max count      mean
# a                                    ...
# -1.293603 -0.244870   1.0 -0.093482  ... -0.594271 -0.594271   1.0 -0.095869
# -0.880555  0.878501   1.0  0.423986  ... -1.316471 -1.316471   1.0 -0.095869
#  1.886550 -0.074228   1.0  0.648857  ...  0.778549  0.778549   1.0 -0.095869
#
#
#           std       min       25%       50%       75%       max
# a
# -1.293603 NaN -0.095869 -0.095869 -0.095869 -0.095869 -0.095869
# -0.880555 NaN -0.095869 -0.095869 -0.095869 -0.095869 -0.095869
#  1.886550 NaN -0.095869 -0.095869 -0.095869 -0.095869 -0.095869
#
# [3 rows x 32 columns]

# %%
data.groupby('a').describe().iloc[1]
# Out:
# b     count    1.000000
#       mean     0.878501
#       std           NaN
#       min      0.878501
#       25%      0.878501
#       50%      0.878501
#       75%      0.878501
#       max      0.878501
# c     count    1.000000
#       mean     0.423986
#       std           NaN
#       min      0.423986
#       25%      0.423986
#       50%      0.423986
#       75%      0.423986
#       max      0.423986
# d     count    1.000000
#       mean    -1.316471
#       std           NaN
#       min     -1.316471
#       25%     -1.316471
#       50%     -1.316471
#       75%     -1.316471
#       max     -1.316471
# None  count    1.000000
#       mean    -0.095869
#       std           NaN
#       min     -0.095869
#       25%     -0.095869
#       50%     -0.095869
#       75%     -0.095869
#       max     -0.095869
# Name: -0.8805551568648783, dtype: float64

# %%
data.groupby('a').describe().index
# Out:
# Float64Index([-1.293603065517899, -0.8805551568648783, 1.8865501902954596], dtype='float64', name='a')

# %%
data.groupby('a').describe().loc[-1.293603065517899]
# Out:
# b     count    1.000000
#       mean    -0.244870
#       std           NaN
#       min     -0.244870
#       25%     -0.244870
#       50%     -0.244870
#       75%     -0.244870
#       max     -0.244870
# c     count    1.000000
#       mean    -0.093482
#       std           NaN
#       min     -0.093482
#       25%     -0.093482
#       50%     -0.093482
#       75%     -0.093482
#       max     -0.093482
# d     count    1.000000
#       mean    -0.594271
#       std           NaN
#       min     -0.594271
#       25%     -0.594271
#       50%     -0.594271
#       75%     -0.594271
#       max     -0.594271
# None  count    1.000000
#       mean    -0.095869
#       std           NaN
#       min     -0.095869
#       25%     -0.095869
#       50%     -0.095869
#       75%     -0.095869
#       max     -0.095869
# Name: -1.293603065517899, dtype: float64

# %%
data.groupby('a').describe().T
# Out:
# a           -1.293603  -0.880555   1.886550
# b    count   1.000000   1.000000   1.000000
#      mean   -0.244870   0.878501  -0.074228
#      std          NaN        NaN        NaN
#      min    -0.244870   0.878501  -0.074228
#      25%    -0.244870   0.878501  -0.074228
#      50%    -0.244870   0.878501  -0.074228
#      75%    -0.244870   0.878501  -0.074228
#      max    -0.244870   0.878501  -0.074228
# c    count   1.000000   1.000000   1.000000
#      mean   -0.093482   0.423986   0.648857
#      std          NaN        NaN        NaN
#      min    -0.093482   0.423986   0.648857
#      25%    -0.093482   0.423986   0.648857
#      50%    -0.093482   0.423986   0.648857
#      75%    -0.093482   0.423986   0.648857
#      max    -0.093482   0.423986   0.648857
# d    count   1.000000   1.000000   1.000000
#      mean   -0.594271  -1.316471   0.778549
#      std          NaN        NaN        NaN
#      min    -0.594271  -1.316471   0.778549
#      25%    -0.594271  -1.316471   0.778549
#      50%    -0.594271  -1.316471   0.778549
#      75%    -0.594271  -1.316471   0.778549
#      max    -0.594271  -1.316471   0.778549
# None count   1.000000   1.000000   1.000000
#      mean   -0.095869  -0.095869  -0.095869
#      std          NaN        NaN        NaN
#      min    -0.095869  -0.095869  -0.095869
#      25%    -0.095869  -0.095869  -0.095869
#      50%    -0.095869  -0.095869  -0.095869
#      75%    -0.095869  -0.095869  -0.095869
#      max    -0.095869  -0.095869  -0.095869

# %%
df1=pd.DataFrame(np.random.rand(3,4),columns=['a','b','c','d'])

# %%
df1
# Out:
#           a         b         c         d
# 0  0.427304  0.186631  0.802365  0.873086
# 1  0.278882  0.740178  0.794560  0.682396
# 2  0.532980  0.871743  0.899185  0.951446

# %%
df2=pd.DataFrame(np.random.rand(3,4),columns=['a','b','c','d'])
df2
# Out:
#           a         b         c         d
# 0  0.100435  0.141436  0.411649  0.521733
# 1  0.886214  0.488636  0.082474  0.446779
# 2  0.965652  0.933366  0.698997  0.400661

# %%
df3=pd.DataFrame(np.random.rand(3,4),columns=['a','b','c','d'])
df3
# Out:
#           a         b         c         d
# 0  0.153035  0.181366  0.472881  0.379295
# 1  0.946492  0.066709  0.351794  0.771015
# 2  0.151751  0.362436  0.598636  0.116533

# %%
pd.concat([df1,df2,df3])
# Out:
#           a         b         c         d
# 0  0.427304  0.186631  0.802365  0.873086
# 1  0.278882  0.740178  0.794560  0.682396
# 2  0.532980  0.871743  0.899185  0.951446
# 0  0.948556  0.800206  0.873089  0.733406
# 1  0.266587  0.006077  0.502350  0.658404
# 2  0.600960  0.478003  0.716756  0.031710
# 0  0.153035  0.181366  0.472881  0.379295
# 1  0.946492  0.066709  0.351794  0.771015
# 2  0.151751  0.362436  0.598636  0.116533

# %%
pd.concat([df1,df2,df3],1)
# Out:
#           a         b         c         d         a         b         c  \
# 0  0.427304  0.186631  0.802365  0.873086  0.948556  0.800206  0.873089
# 1  0.278882  0.740178  0.794560  0.682396  0.266587  0.006077  0.502350
# 2  0.532980  0.871743  0.899185  0.951446  0.600960  0.478003  0.716756
#
#           d         a         b         c         d
# 0  0.733406  0.153035  0.181366  0.472881  0.379295
# 1  0.658404  0.946492  0.066709  0.351794  0.771015
# 2  0.031710  0.151751  0.362436  0.598636  0.116533
