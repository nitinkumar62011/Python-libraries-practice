# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.DataFrame(np.random.randn(1000,1),index=pd.date_range('2020-11-11',periods=1000),columns=['a'])

# %%
df
# Out:
#                    a
# 2020-11-11  0.137180
# 2020-11-12  0.261384
# 2020-11-13 -0.187350
# 2020-11-14  1.412317
# 2020-11-15 -1.009707
# ...              ...
# 2023-08-03 -0.308251
# 2023-08-04  1.086466
# 2023-08-05 -1.289342
# 2023-08-06 -0.276847
# 2023-08-07  1.122216
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
df['cumsum_data']=df.cumsum()

# %%
df
# Out:
#                    a  cumsum_data
# 2020-11-11  0.137180     0.137180
# 2020-11-12  0.261384     0.398564
# 2020-11-13 -0.187350     0.211214
# 2020-11-14  1.412317     1.623531
# 2020-11-15 -1.009707     0.613823
# ...              ...          ...
# 2023-08-03 -0.308251   -32.671142
# 2023-08-04  1.086466   -31.584676
# 2023-08-05 -1.289342   -32.874018
# 2023-08-06 -0.276847   -33.150864
# 2023-08-07  1.122216   -32.028648
#
# [1000 rows x 2 columns]

# %%
df['square_data']=df.cumsum_data.apply(lambda x:x**2)

# %%
df
# Out:
#                    a  cumsum_data  square_data
# 2020-11-11  0.137180     0.137180     0.018818
# 2020-11-12  0.261384     0.398564     0.158853
# 2020-11-13 -0.187350     0.211214     0.044611
# 2020-11-14  1.412317     1.623531     2.635852
# 2020-11-15 -1.009707     0.613823     0.376779
# ...              ...          ...          ...
# 2023-08-03 -0.308251   -32.671142  1067.403522
# 2023-08-04  1.086466   -31.584676   997.591738
# 2023-08-05 -1.289342   -32.874018  1080.701040
# 2023-08-06 -0.276847   -33.150864  1098.979798
# 2023-08-07  1.122216   -32.028648  1025.834275
#
# [1000 rows x 3 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
data=sns.load_dataset('iris')

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
gf=data.plot(figsize=(10,10),title='iris_dataset')
gf.set_xlabel("x axis")
gf.set_ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
data.iloc[0][0:4].plot()
# Out:
# <AxesSubplot:>

# %%
data.iloc[0][0:4].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data2=sns.load_dataset('titanic')

# %%
data2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2=pd.DataFrame(np.random.randn(10,3),columns=['a','b','c'])

# %%
df2
# Out:
#           a         b         c
# 0  0.938192  0.233395  0.167378
# 1  0.619619 -0.508332 -0.470150
# 2 -0.035878  0.125058  0.650817
# 3 -0.998045 -0.638497 -0.795774
# 4  0.255364 -1.087184 -2.077529
# 5 -1.724727  0.858582 -0.224752
# 6 -0.848456 -2.156168  1.412387
# 7 -0.406908  0.815142 -1.354676
# 8 -2.400065  0.724974 -1.789780
# 9  0.791396  0.615383 -1.119085

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
data.plot.hist(bins=30,stacked=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.plot.hist(bins=30,stacked=True, orientation='horizontal',figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
data.plot.scatter(x='sepal_length',y='sepal_width',c='petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
data.sepal_width.plot.pie(subplots=True)
# Out:
# array([<AxesSubplot:ylabel='sepal_width'>], dtype=object)

# %%
data.iloc[0][0:4].T.plot.pie(subplots=True)
# Out:
# array([<AxesSubplot:ylabel='0'>], dtype=object)

# %%
pd.DataFrame(data.iloc[0][0:4]).T
# Out:
#   sepal_length sepal_width petal_length petal_width
# 0          5.1         3.5          1.4         0.2

# %%
pd.DataFrame(data.iloc[0][0:4]).T.plot.pie(subplots=True)
# Out:
# C:\Users\nitin\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1547: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# array([<AxesSubplot:ylabel='sepal_length'>,
#        <AxesSubplot:ylabel='sepal_width'>,
#        <AxesSubplot:ylabel='petal_length'>,
#        <AxesSubplot:ylabel='petal_width'>], dtype=object)

# %%
pd.plotting.scatter_matrix(data,figsize=(10,10),diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# !pip install plotly
# !pip install cufflinks
# Out:
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      -------------------------------------- 81.7/81.7 kB 572.0 kB/s eta 0:00:00
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68727 sha256=7a2d3102b869d6a9ebb1c23300543eba28ddaa0f30093c1bb1f9d98ab297e605
#   Stored in directory: c:\users\nitin\appdata\local\pip\cache\wheels\6b\76\62\6da97734911ffcbdd559fd1a3f28526321f0ae699182a23866
# Successfully built cufflinks
# ...

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as pt
import cufflinks as cu

# %%
py.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cu.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=sns.load_dataset('titanic')

# %%
data.iplot()
# Out:
# <div>                            <div id="73393d6d-1de3-489f-bab7-88b7eacc319f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='fare',y='age',mode='markers',kind='scatter')
# Out:
# <div>                            <div id="113714a2-50e3-409f-b981-8498e27d550e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
